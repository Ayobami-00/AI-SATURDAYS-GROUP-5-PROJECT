# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Ayobami-00/AI-SATURDAYS-GROUP-5-PROJECT/blob/master/AI_SATURDAYS_GROUP_5_PROJECT.ipynb)

# %% [markdown]
# # Group Project
#
# This notebook along with the [TensorFlow and deep learning, without a PhD](https://codelabs.developers.google.com/codelabs/cloud-tensorflow-mnist/#0) codelabs should serve as a starter guide for your group projects. For the project, you are to build a model that achieves a minimum of 96% accuracy for a classification task on the MNIST dataset. This can be achieved by several methods, but you are required to follow some certain steps as outlined below:
#
# 1. Load the mnist dataset from tensorflow. This consists of the train, validation, and test sets.
#     The train set has 55000 examples,
#     The validation set has 5000 examples, and
#     the test set has 10000 examples.
#
# 2. Visualize the examples in each set.
#
# 3. Build a softmax regression model (a 1 layer neural network)and train it on the dataset.
#
# 4. Add a hidden layer of 200 neurons, use sigmoid activation for hidden units, train and obtain train, validation and test accuracies and loss
#
# 5. Build a five layers neural network with sigmoid activation
#
# 6. Replace the sigmoid activations with relu
#
# 7. Introduce learning rate decay
#
# 8. Use dropout
#
# 9. Convolutional Neural Networks

# %%
#@title All imports and Initializations(RUN THIS CELL!)
'''
Obtain MNIST dataset using tensorflow
'''
import tensorflow as tf
import math
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt

mnist = input_data.read_data_sets('data/fashion', source_url='http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/', one_hot=True)

fashion_class = {0:'shirt/top',
                1: 	'Trouser',
                2: 	'Pullover',
                3: 	'Dress',
                4: 	'Coat',
                5: 	'Sandal',
                6: 	'Shirt',
                7: 	'Sneaker',
                8: 	'Bag',
                9: 	'Ankle boot'
                }

def view_image(x,y):
  '''
  View 10 random images from a dataset
  
  input:
    x => ndarray[of shape (m x n)] (examples)
    y => ndarray[of shape (m x c)] (onehot encoded)
          m = no of examples
          c = no of classes
  output:
    None.
   
  '''
  f, axarr = plt.subplots(2,5)
  
  for ax in f.axes:
    i = np.random.randint(x.shape[0]) # pick a random example (ith example)
    ax.get_xaxis().set_ticks([]) # don't label the xaxis
    ax.get_yaxis().set_ticks([]) # don't label the yais
    ax.text(0,0, fashion_class[np.argmax(y[i])]) # display a text containing the ith example's class
    ax.imshow(x[i].reshape(28,28)) # display the ith example

    
    
# This function does the training

def training(X_train, y_train, X_val, y_val, sess, epochs = 1, mini_batch = 100, step=None, pkeep=None):
  
    '''
    **arguments**
    X_train:
      The input feature matrix
    y_train:
      The output true label
    X_val:
      The validation set feature matrix
    y_val:
      The validation set true label
    sess:
      A tensorflow session to run the computational graph
    epochs:
      No of times to run through the entire examples 
    mini_batch:
      No of examples to use in each train step
      
      
    **returns**
    history: tuple
      a tuple containing the train and validation accuracies and losses
      
    '''
    
    accuracies = []
    loss = []
    accuracies_validation = []
    loss_validation = []
    
    steps_per_epoch = int(X_train.shape[0]/mini_batch)
    training_steps = epochs * steps_per_epoch
  
    for i in range(1,training_steps+1):
      # pick a mini batch from the training
      s = i%steps_per_epoch
      batch_X, batch_Y = X_train[(s-1)*mini_batch:(s)*mini_batch], y_train[(s-1)*mini_batch:(s)*mini_batch]

      # compute train/validation loss and accuracy
      if i%steps_per_epoch == 0:
          # train
          if(step != None and pkeep == None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_train, y: y_train})
          if(step == None and pkeep != None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_train, y: y_train, pkeep_val: pkeep})
          if(step != None and pkeep != None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_train, y: y_train, pkeep_val: pkeep})
          if(step == None and pkeep == None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_train, y: y_train})
          loss.append(c)
          accuracies.append(a)
          print("EPOCH " + str(i/steps_per_epoch) + "\n" + " train accuracy:" + str(a) + "train loss: " + str(c))
          
          # validation
          if(step != None and pkeep == None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_val, y: y_val})
          if(step == None and pkeep != None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_val, y: y_val, pkeep_val: 1})
          if(step != None and pkeep != None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_val, y: y_val, pkeep_val: 1})
          if(step == None and pkeep == None):
            a, c = sess.run([accuracy, cross_entropy], feed_dict={X: X_val, y: y_val})
         
          loss_validation.append(c)
          accuracies_validation.append(a)
          print(" ********* validation accuracy:" + str(a) + " validation loss: " + str(c))

      # the backpropagation training step
     
      if(step != None and pkeep == None):
        sess.run(train_step, feed_dict={X: batch_X, y: batch_Y, step_val: i})
      if(step == None and pkeep != None):
        sess.run(train_step, feed_dict={X: batch_X, y: batch_Y, pkeep_val: pkeep})
      if(step != None and pkeep != None):
        sess.run([train_step], feed_dict={X: X_val, y: y_val, step_val: i, pkeep_val: pkeep})
      if(step == None and pkeep == None):
        sess.run(train_step, feed_dict={X: X_val, y: y_val})
         
      
      history = (accuracies, loss, accuracies_validation, loss_validation)
      
    return history
  


def plot_history(history):
  accuracies, loss, accuracies_validation, loss_validation = history
  f, ax = plt.subplots(2,2)
  ax[0,0].plot(accuracies)
  ax[0,0].set(xlabel='epochs', ylabel='train_accuracy')

  ax[0,1].plot(loss )
  ax[0,1].set(xlabel='epochs', ylabel='train_loss')

  ax[1,0].plot(accuracies_validation)
  ax[1,0].set(xlabel='epochs', ylabel='val_accuracy')


  ax[1,1].plot(loss_validation)
  ax[1,1].set(xlabel='epochs', ylabel='val_loss')
# Out:
# Extracting data/fashion/train-images-idx3-ubyte.gz
# Extracting data/fashion/train-labels-idx1-ubyte.gz
# Extracting data/fashion/t10k-images-idx3-ubyte.gz
# Extracting data/fashion/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## 1. Load the dataset
# for the train set, x_train contains the 55000 train images and y_train contains the onehot encoded label. Same applies to the validation and test set

# %%
x_train = mnist.train.images
y_train = mnist.train.labels
x_val = mnist.validation.images
y_val = mnist.validation.labels
x_test = mnist.test.images
y_test = mnist.test.labels

# %% [markdown]
# The train images are 28x28 gray scale images. But the loaded images are flattened to be of size (1x784). Hence the size of the train set images is 55000 by 784. this means that there are 55000 examples of size (28*28=784). The same applies to the validation and test set

# %%
print('shape of train set is: {0}, this means that it has {1} examples'.format(x_train.shape, x_train.shape[0]))
print('shape of validation set is: {0}, this means that it has {1} examples'.format(x_val.shape, x_val.shape[0]))
print('shape of test set is: {0}, this means that it has {1} examples'.format(x_test.shape, x_test.shape[0]))
# Out:
# shape of train set is: (55000, 784), this means that it has 55000 examples
# shape of validation set is: (5000, 784), this means that it has 5000 examples
# shape of test set is: (10000, 784), this means that it has 10000 examples

# %% [markdown]
# ## 2. Visualize examples in each set

# %% [markdown]
# View 10 random examples from train, validation and test set

# %% [markdown]
# View 10 random images from the train set

# %%
view_image(x_train, y_train)

# %% [markdown]
# View 10 random images from the validation set

# %%
view_image(x_val, y_val)

# %% [markdown]
# View 10 random images from the test set

# %%
view_image(x_test, y_test)

# %% [markdown]
# ## 3. Build a softmax regression model (a 1 layer neural network)and train it on the dataset.
#
#
# Build Computational Graph

# %%
# input 
X = tf.placeholder(tf.float32, [None,784])
# labels (onehot encoded)
y = tf.placeholder(tf.float32, [None, 10])
# weights
W = tf.Variable(tf.zeros([784, 10]))
# biases
b = tf.Variable(tf.zeros([10]))

# weigthed sum
z = tf.matmul(X, W) + b

# softmax activation
h = tf.nn.softmax(z)

# softmax cross entropy loss
cross_entropy = -tf.reduce_mean(y * tf.log(h))

# accuracy of the trained model, between 0 (worst) and 1 (best)
correct_prediction = tf.equal(tf.argmax(h, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# training, learning rate = 0.005
# learning rate
lr = 0.005
train_step = tf.train.GradientDescentOptimizer(lr).minimize(cross_entropy)

# %% [markdown]
# Start the session

# %%
# initialize all variables
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %% [markdown]
# Train for 100 epochs

# %%
history = training(x_train, y_train, x_val, y_val, sess, epochs=100)
# Out:
# EPOCH 1.0
#  train accuracy:0.62756366train loss: 0.1831179
#  ********* validation accuracy:0.6408 validation loss: 0.182067
# EPOCH 2.0
#  train accuracy:0.6529818train loss: 0.15653014
#  ********* validation accuracy:0.665 validation loss: 0.15495725
# EPOCH 3.0
#  train accuracy:0.6616909train loss: 0.13951589
#  ********* validation accuracy:0.6718 validation loss: 0.13768423
# EPOCH 4.0
#  train accuracy:0.66654545train loss: 0.12784451
#  ********* validation accuracy:0.6746 validation loss: 0.12586218
# EPOCH 5.0
#  train accuracy:0.66965455train loss: 0.11936973
#  ********* validation accuracy:0.6796 validation loss: 0.11728464
# EPOCH 6.0
#  train accuracy:0.67398185train loss: 0.112931944
#  ********* validation accuracy:0.6836 validation loss: 0.1107678
# EPOCH 7.0
#  train accuracy:0.67925453train loss: 0.10786297
#  ********* validation accuracy:0.69 validation loss: 0.105632745
# EPOCH 8.0
#  train accuracy:0.68405455train loss: 0.103754856
#  ********* validation accuracy:0.6972 validation loss: 0.101466425
# EPOCH 9.0
#  train accuracy:0.69train loss: 0.10034613
#  ********* validation accuracy:0.7042 validation loss: 0.09800465
# EPOCH 10.0
#  train accuracy:0.6954909train loss: 0.0974621
#  ********* validation accuracy:0.712 validation loss: 0.09507125
# EPOCH 11.0
#  train accuracy:0.7023818train loss: 0.09498196
#  ********* validation accuracy:0.7188 validation loss: 0.09254452
# EPOCH 12.0
#  train accuracy:0.70829093train loss: 0.092819616
#  ********* validation accuracy:0.7236 validation loss: 0.09033782
# EPOCH 13.0
#  train accuracy:0.7134727train loss: 0.09091215
#  ********* validation accuracy:0.7304 validation loss: 0.088387854
# EPOCH 14.0
#  train accuracy:0.7193273train loss: 0.08921251
#  ********* validation accuracy:0.735 validation loss: 0.086647265
# EPOCH 15.0
#  train accuracy:0.7236909train loss: 0.08768481
#  ********* validation accuracy:0.7392 validation loss: 0.08508004
# EPOCH 16.0
#  train accuracy:0.72816366train loss: 0.08630121
#  ********* validation accuracy:0.7432 validation loss: 0.08365812
# EPOCH 17.0
#  train accuracy:0.73163635train loss: 0.08503975
#  ********* validation accuracy:0.7474 validation loss: 0.08235949
# EPOCH 18.0
#  train accuracy:0.73456365train loss: 0.0838829
#  ********* validation accuracy:0.7518 validation loss: 0.08116649
# EPOCH 19.0
#  train accuracy:0.73734546train loss: 0.08281644
#  ********* validation accuracy:0.755 validation loss: 0.080064826
# EPOCH 20.0
#  train accuracy:0.7402545train loss: 0.08182873
#  ********* validation accuracy:0.7562 validation loss: 0.079042785
# EPOCH 21.0
#  train accuracy:0.7430909train loss: 0.08091016
#  ********* validation accuracy:0.7592 validation loss: 0.07809069
# EPOCH 22.0
#  train accuracy:0.7454909train loss: 0.08005269
#  ********* validation accuracy:0.7626 validation loss: 0.07720046
# EPOCH 23.0
#  train accuracy:0.74798185train loss: 0.07924956
#  ********* validation accuracy:0.7662 validation loss: 0.076365255
# EPOCH 24.0
#  train accuracy:0.7500727train loss: 0.078494996
#  ********* validation accuracy:0.7688 validation loss: 0.07557928
# EPOCH 25.0
#  train accuracy:0.7518727train loss: 0.0777841
#  ********* validation accuracy:0.7702 validation loss: 0.07483758
# EPOCH 26.0
#  train accuracy:0.75372726train loss: 0.07711264
#  ********* validation accuracy:0.7734 validation loss: 0.07413588
# EPOCH 27.0
#  train accuracy:0.75552726train loss: 0.076476924
#  ********* validation accuracy:0.7752 validation loss: 0.07347048
# EPOCH 28.0
#  train accuracy:0.75683635train loss: 0.07587378
#  ********* validation accuracy:0.7764 validation loss: 0.07283814
# EPOCH 29.0
#  train accuracy:0.75885457train loss: 0.07530039
#  ********* validation accuracy:0.7776 validation loss: 0.07223604
# EPOCH 30.0
#  train accuracy:0.76074547train loss: 0.074754305
#  ********* validation accuracy:0.7794 validation loss: 0.07166167
# EPOCH 31.0
#  train accuracy:0.7622train loss: 0.07423333
#  ********* validation accuracy:0.7822 validation loss: 0.07111284
# EPOCH 32.0
#  train accuracy:0.7632727train loss: 0.073735535
#  ********* validation accuracy:0.7836 validation loss: 0.07058758
# EPOCH 33.0
#  train accuracy:0.76463634train loss: 0.07325919
#  ********* validation accuracy:0.7844 validation loss: 0.07008414
# EPOCH 34.0
#  train accuracy:0.76607275train loss: 0.072802745
#  ********* validation accuracy:0.7864 validation loss: 0.06960095
# EPOCH 35.0
#  train accuracy:0.76747274train loss: 0.0723648
#  ********* validation accuracy:0.789 validation loss: 0.06913659
# EPOCH 36.0
#  train accuracy:0.76894546train loss: 0.0719441
#  ********* validation accuracy:0.7898 validation loss: 0.06868979
# EPOCH 37.0
#  train accuracy:0.7702364train loss: 0.07153953
#  ********* validation accuracy:0.7904 validation loss: 0.06825941
# EPOCH 38.0
#  train accuracy:0.7714546train loss: 0.07115006
#  ********* validation accuracy:0.792 validation loss: 0.0678444
# EPOCH 39.0
#  train accuracy:0.7728364train loss: 0.07077472
#  ********* validation accuracy:0.7926 validation loss: 0.067443796
# EPOCH 40.0
#  train accuracy:0.7740545train loss: 0.07041267
#  ********* validation accuracy:0.7934 validation loss: 0.06705673
# EPOCH 41.0
#  train accuracy:0.7749091train loss: 0.07006312
#  ********* validation accuracy:0.7948 validation loss: 0.06668243
# EPOCH 42.0
#  train accuracy:0.77590907train loss: 0.06972539
#  ********* validation accuracy:0.7958 validation loss: 0.066320136
# EPOCH 43.0
#  train accuracy:0.77687275train loss: 0.06939877
#  ********* validation accuracy:0.7968 validation loss: 0.06596919
# EPOCH 44.0
#  train accuracy:0.7779273train loss: 0.06908266
#  ********* validation accuracy:0.7972 validation loss: 0.06562897
# EPOCH 45.0
#  train accuracy:0.7788train loss: 0.068776526
#  ********* validation accuracy:0.7984 validation loss: 0.06529891
# EPOCH 46.0
#  train accuracy:0.7798182train loss: 0.06847982
#  ********* validation accuracy:0.7994 validation loss: 0.06497849
# EPOCH 47.0
#  train accuracy:0.78072727train loss: 0.06819208
#  ********* validation accuracy:0.8008 validation loss: 0.064667195
# EPOCH 48.0
#  train accuracy:0.7816727train loss: 0.06791285
#  ********* validation accuracy:0.8016 validation loss: 0.0643646
# EPOCH 49.0
#  train accuracy:0.7826train loss: 0.067641705
#  ********* validation accuracy:0.8022 validation loss: 0.06407025
# EPOCH 50.0
#  train accuracy:0.78336364train loss: 0.067378275
#  ********* validation accuracy:0.8022 validation loss: 0.06378378
# EPOCH 51.0
#  train accuracy:0.78403634train loss: 0.06712219
#  ********* validation accuracy:0.803 validation loss: 0.063504815
# EPOCH 52.0
#  train accuracy:0.7848182train loss: 0.06687312
#  ********* validation accuracy:0.8038 validation loss: 0.06323301
# EPOCH 53.0
#  train accuracy:0.7856train loss: 0.066630736
#  ********* validation accuracy:0.8044 validation loss: 0.062968045
# EPOCH 54.0
#  train accuracy:0.7863273train loss: 0.06639475
#  ********* validation accuracy:0.805 validation loss: 0.06270961
# EPOCH 55.0
#  train accuracy:0.7868182train loss: 0.06616488
#  ********* validation accuracy:0.8066 validation loss: 0.06245743
# EPOCH 56.0
#  train accuracy:0.7872546train loss: 0.065940864
#  ********* validation accuracy:0.8066 validation loss: 0.06221124
# EPOCH 57.0
#  train accuracy:0.78792727train loss: 0.065722466
#  ********* validation accuracy:0.807 validation loss: 0.061970793
# EPOCH 58.0
#  train accuracy:0.7884train loss: 0.065509446
#  ********* validation accuracy:0.8076 validation loss: 0.061735854
# EPOCH 59.0
#  train accuracy:0.7890546train loss: 0.06530159
#  ********* validation accuracy:0.8086 validation loss: 0.0615062
# EPOCH 60.0
#  train accuracy:0.7894545train loss: 0.0650987
#  ********* validation accuracy:0.8102 validation loss: 0.06128162
# EPOCH 61.0
#  train accuracy:0.7900182train loss: 0.06490058
#  ********* validation accuracy:0.8106 validation loss: 0.061061922
# EPOCH 62.0
#  train accuracy:0.7907091train loss: 0.064707026
#  ********* validation accuracy:0.8112 validation loss: 0.060846914
# EPOCH 63.0
#  train accuracy:0.7912727train loss: 0.06451789
#  ********* validation accuracy:0.8128 validation loss: 0.06063643
# EPOCH 64.0
#  train accuracy:0.7919091train loss: 0.064333
#  ********* validation accuracy:0.8136 validation loss: 0.060430303
# EPOCH 65.0
#  train accuracy:0.7927455train loss: 0.06415219
#  ********* validation accuracy:0.814 validation loss: 0.060228348
# EPOCH 66.0
#  train accuracy:0.79318184train loss: 0.06397533
#  ********* validation accuracy:0.8156 validation loss: 0.06003045
# EPOCH 67.0
#  train accuracy:0.7935454train loss: 0.06380226
#  ********* validation accuracy:0.8164 validation loss: 0.059836444
# EPOCH 68.0
#  train accuracy:0.7942182train loss: 0.06363287
#  ********* validation accuracy:0.8168 validation loss: 0.05964621
# EPOCH 69.0
#  train accuracy:0.7946909train loss: 0.06346701
#  ********* validation accuracy:0.817 validation loss: 0.059459608
# EPOCH 70.0
#  train accuracy:0.7950364train loss: 0.063304566
#  ********* validation accuracy:0.8182 validation loss: 0.059276517
# EPOCH 71.0
#  train accuracy:0.7954train loss: 0.06314544
#  ********* validation accuracy:0.8182 validation loss: 0.059096824
# EPOCH 72.0
#  train accuracy:0.7958182train loss: 0.062989496
#  ********* validation accuracy:0.8186 validation loss: 0.058920413
# EPOCH 73.0
#  train accuracy:0.79614544train loss: 0.06283665
#  ********* validation accuracy:0.819 validation loss: 0.058747187
# EPOCH 74.0
#  train accuracy:0.7965091train loss: 0.062686786
#  ********* validation accuracy:0.8192 validation loss: 0.058577035
# EPOCH 75.0
#  train accuracy:0.7970909train loss: 0.06253982
#  ********* validation accuracy:0.8198 validation loss: 0.058409862
# EPOCH 76.0
#  train accuracy:0.7974727train loss: 0.062395666
#  ********* validation accuracy:0.8206 validation loss: 0.05824558
# EPOCH 77.0
#  train accuracy:0.79785454train loss: 0.06225423
#  ********* validation accuracy:0.8214 validation loss: 0.0580841
# EPOCH 78.0
#  train accuracy:0.7982727train loss: 0.06211542
#  ********* validation accuracy:0.8216 validation loss: 0.05792533
# EPOCH 79.0
#  train accuracy:0.79865456train loss: 0.06197917
#  ********* validation accuracy:0.8224 validation loss: 0.057769198
# EPOCH 80.0
#  train accuracy:0.79890907train loss: 0.061845392
#  ********* validation accuracy:0.8222 validation loss: 0.057615615
# EPOCH 81.0
#  train accuracy:0.79916364train loss: 0.061714027
#  ********* validation accuracy:0.8232 validation loss: 0.05746452
# EPOCH 82.0
#  train accuracy:0.79956365train loss: 0.061584987
#  ********* validation accuracy:0.8234 validation loss: 0.057315834
# EPOCH 83.0
#  train accuracy:0.7999273train loss: 0.06145822
#  ********* validation accuracy:0.8236 validation loss: 0.057169493
# EPOCH 84.0
#  train accuracy:0.8000364train loss: 0.06133365
#  ********* validation accuracy:0.8238 validation loss: 0.05702542
# EPOCH 85.0
#  train accuracy:0.8000909train loss: 0.061211236
#  ********* validation accuracy:0.8246 validation loss: 0.056883585
# EPOCH 86.0
#  train accuracy:0.8005091train loss: 0.061090894
#  ********* validation accuracy:0.8258 validation loss: 0.056743886
# EPOCH 87.0
#  train accuracy:0.80087274train loss: 0.06097257
#  ********* validation accuracy:0.8268 validation loss: 0.05660629
# EPOCH 88.0
#  train accuracy:0.80096364train loss: 0.06085621
#  ********* validation accuracy:0.8274 validation loss: 0.056470722
# EPOCH 89.0
#  train accuracy:0.80134547train loss: 0.060741782
#  ********* validation accuracy:0.8278 validation loss: 0.056337144
# EPOCH 90.0
#  train accuracy:0.8016train loss: 0.06062922
#  ********* validation accuracy:0.8282 validation loss: 0.056205507
# EPOCH 91.0
#  train accuracy:0.8020727train loss: 0.060518466
#  ********* validation accuracy:0.8288 validation loss: 0.056075748
# EPOCH 92.0
#  train accuracy:0.8023818train loss: 0.06040946
#  ********* validation accuracy:0.829 validation loss: 0.05594782
# EPOCH 93.0
#  train accuracy:0.80265456train loss: 0.060302194
#  ********* validation accuracy:0.8292 validation loss: 0.05582169
# EPOCH 94.0
#  train accuracy:0.8029091train loss: 0.06019662
#  ********* validation accuracy:0.83 validation loss: 0.055697303
# EPOCH 95.0
#  train accuracy:0.8031273train loss: 0.06009267
#  ********* validation accuracy:0.8306 validation loss: 0.05557462
# EPOCH 96.0
#  train accuracy:0.80334544train loss: 0.059990298
#  ********* validation accuracy:0.8312 validation loss: 0.055453572
# EPOCH 97.0
#  train accuracy:0.8036364train loss: 0.059889518
#  ********* validation accuracy:0.8318 validation loss: 0.055334173
# EPOCH 98.0
#  train accuracy:0.80390906train loss: 0.059790228
#  ********* validation accuracy:0.8322 validation loss: 0.055216346
# EPOCH 99.0
#  train accuracy:0.80430907train loss: 0.059692416
#  ********* validation accuracy:0.833 validation loss: 0.05510005
# EPOCH 100.0
#  train accuracy:0.80472726train loss: 0.059596065
#  ********* validation accuracy:0.8334 validation loss: 0.054985285

# %% [markdown]
# plot the train and validation acurracy and loss against the number of epochs

# %%
plot_history(history)

# %% [markdown]
# Obtain the test accuracy

# %%
a_test, c_test  = sess.run([accuracy, cross_entropy], feed_dict={X: x_test, y: y_test})

print('Test accuracy is: ', ("%.2f"%(a_test*100))+'%')
# Out:
# Test accuracy is:  79.29%

# %%
sess.close()

# %% [markdown]
# You can try increasing the number of epochs for better accuracy

# %% [markdown]
# ## 4. Add a hidden layer of 200 neurons, use sigmoid activation for hidden units, train and obtain train, validation and test accuracies and loss
#
# Computational graph

# %%
#Create computational graph

# input 
X = tf.placeholder(tf.float32, [None,784])
# labels (onehot encoded)
y = tf.placeholder(tf.float32, [None, 10])

''' First hidden layer with 200 neurons'''
# weights 1
W1 = tf.Variable(tf.truncated_normal([784, 200], stddev=0.1))
# biases 1
b1 = tf.Variable(tf.zeros([200]))

# weigthed sum
z1 = tf.matmul(X, W1) + b1

#  activation
h1 = tf.nn.sigmoid(z1)


''' Second/output Layer'''
# weights 2
W2 = tf.Variable(tf.truncated_normal([200, 10], stddev=0.1))
# biases 2
b2 = tf.Variable(tf.zeros([10]))

# weigthed sum
z2 = tf.matmul(h1, W2) + b2

# softmax activation
h2 = tf.nn.softmax(z2)

# softmax cross entropy loss
cross_entropy = -tf.reduce_mean(y * tf.log(h2))

# accuracy of the trained model, between 0 (worst) and 1 (best)
correct_prediction = tf.equal(tf.argmax(h2, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# training, learning rate = 0.005
# learning rate
lr = 0.005
train_step = tf.train.GradientDescentOptimizer(lr).minimize(cross_entropy)

# %% [markdown]
# Start session

# %%
#Start session

# initialize all variables
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %%
history = training(x_train, y_train, x_val, y_val, sess, epochs=100)
# Out:
# EPOCH 1.0
#  train accuracy:0.24681818train loss: 0.22035432
#  ********* validation accuracy:0.2474 validation loss: 0.22048932
# EPOCH 2.0
#  train accuracy:0.35241818train loss: 0.21208137
#  ********* validation accuracy:0.3534 validation loss: 0.21204329
# EPOCH 3.0
#  train accuracy:0.44730908train loss: 0.20463517
#  ********* validation accuracy:0.447 validation loss: 0.20442277
# EPOCH 4.0
#  train accuracy:0.48314545train loss: 0.19767188
#  ********* validation accuracy:0.4818 validation loss: 0.19729695
# EPOCH 5.0
#  train accuracy:0.50496364train loss: 0.19113787
#  ********* validation accuracy:0.5044 validation loss: 0.19061524
# EPOCH 6.0
#  train accuracy:0.52230906train loss: 0.18500254
#  ********* validation accuracy:0.521 validation loss: 0.1843467
# EPOCH 7.0
#  train accuracy:0.5385818train loss: 0.17924261
#  ********* validation accuracy:0.5358 validation loss: 0.178467
# EPOCH 8.0
#  train accuracy:0.5564train loss: 0.17383811
#  ********* validation accuracy:0.5556 validation loss: 0.17295507
# EPOCH 9.0
#  train accuracy:0.5712364train loss: 0.16877042
#  ********* validation accuracy:0.5726 validation loss: 0.1677911
# EPOCH 10.0
#  train accuracy:0.58576363train loss: 0.16402118
#  ********* validation accuracy:0.589 validation loss: 0.16295569
# EPOCH 11.0
#  train accuracy:0.5992182train loss: 0.15957193
#  ********* validation accuracy:0.6036 validation loss: 0.15842935
# EPOCH 12.0
#  train accuracy:0.61309093train loss: 0.15540417
#  ********* validation accuracy:0.6182 validation loss: 0.15419261
# EPOCH 13.0
#  train accuracy:0.6262182train loss: 0.15149947
#  ********* validation accuracy:0.6312 validation loss: 0.15022612
# EPOCH 14.0
#  train accuracy:0.6371273train loss: 0.14783978
#  ********* validation accuracy:0.6452 validation loss: 0.146511
# EPOCH 15.0
#  train accuracy:0.64663637train loss: 0.1444078
#  ********* validation accuracy:0.6546 validation loss: 0.14302912
# EPOCH 16.0
#  train accuracy:0.6550909train loss: 0.14118694
#  ********* validation accuracy:0.6664 validation loss: 0.13976324
# EPOCH 17.0
#  train accuracy:0.6636909train loss: 0.13816151
#  ********* validation accuracy:0.6748 validation loss: 0.13669705
# EPOCH 18.0
#  train accuracy:0.6708364train loss: 0.13531688
#  ********* validation accuracy:0.6816 validation loss: 0.13381532
# EPOCH 19.0
#  train accuracy:0.67645454train loss: 0.13263941
#  ********* validation accuracy:0.688 validation loss: 0.13110395
# EPOCH 20.0
#  train accuracy:0.68054545train loss: 0.13011648
#  ********* validation accuracy:0.6942 validation loss: 0.1285499
# EPOCH 21.0
#  train accuracy:0.6844909train loss: 0.12773648
#  ********* validation accuracy:0.6974 validation loss: 0.12614118
# EPOCH 22.0
#  train accuracy:0.6882909train loss: 0.12548871
#  ********* validation accuracy:0.7026 validation loss: 0.12386677
# EPOCH 23.0
#  train accuracy:0.69192725train loss: 0.12336332
#  ********* validation accuracy:0.7062 validation loss: 0.12171656
# EPOCH 24.0
#  train accuracy:0.6945818train loss: 0.121351376
#  ********* validation accuracy:0.7086 validation loss: 0.11968135
# EPOCH 25.0
#  train accuracy:0.6968182train loss: 0.119444646
#  ********* validation accuracy:0.7108 validation loss: 0.11775269
# EPOCH 26.0
#  train accuracy:0.69936365train loss: 0.117635556
#  ********* validation accuracy:0.7124 validation loss: 0.11592287
# EPOCH 27.0
#  train accuracy:0.7017273train loss: 0.11591724
#  ********* validation accuracy:0.7156 validation loss: 0.11418484
# EPOCH 28.0
#  train accuracy:0.7040909train loss: 0.11428338
#  ********* validation accuracy:0.7182 validation loss: 0.11253215
# EPOCH 29.0
#  train accuracy:0.7061091train loss: 0.11272818
#  ********* validation accuracy:0.7204 validation loss: 0.110958904
# EPOCH 30.0
#  train accuracy:0.70796365train loss: 0.11124637
#  ********* validation accuracy:0.721 validation loss: 0.109459706
# EPOCH 31.0
#  train accuracy:0.7094727train loss: 0.10983304
#  ********* validation accuracy:0.7228 validation loss: 0.10802959
# EPOCH 32.0
#  train accuracy:0.7109454train loss: 0.108483754
#  ********* validation accuracy:0.7246 validation loss: 0.10666402
# EPOCH 33.0
#  train accuracy:0.7124364train loss: 0.10719441
#  ********* validation accuracy:0.7266 validation loss: 0.10535884
# EPOCH 34.0
#  train accuracy:0.7136545train loss: 0.105961226
#  ********* validation accuracy:0.7278 validation loss: 0.104110196
# EPOCH 35.0
#  train accuracy:0.7149818train loss: 0.10478072
#  ********* validation accuracy:0.7286 validation loss: 0.10291459
# EPOCH 36.0
#  train accuracy:0.7164909train loss: 0.10364966
#  ********* validation accuracy:0.7294 validation loss: 0.10176873
# EPOCH 37.0
#  train accuracy:0.71794546train loss: 0.1025651
#  ********* validation accuracy:0.7298 validation loss: 0.10066964
# EPOCH 38.0
#  train accuracy:0.7189636train loss: 0.10152429
#  ********* validation accuracy:0.7312 validation loss: 0.09961453
# EPOCH 39.0
#  train accuracy:0.7202182train loss: 0.10052473
#  ********* validation accuracy:0.7326 validation loss: 0.09860086
# EPOCH 40.0
#  train accuracy:0.7211818train loss: 0.09956402
#  ********* validation accuracy:0.7336 validation loss: 0.09762623
# EPOCH 41.0
#  train accuracy:0.7222546train loss: 0.09864
#  ********* validation accuracy:0.7342 validation loss: 0.09668845
# EPOCH 42.0
#  train accuracy:0.7232909train loss: 0.09775066
#  ********* validation accuracy:0.7356 validation loss: 0.09578547
# EPOCH 43.0
#  train accuracy:0.7244train loss: 0.09689411
#  ********* validation accuracy:0.7378 validation loss: 0.09491541
# EPOCH 44.0
#  train accuracy:0.72532725train loss: 0.09606857
#  ********* validation accuracy:0.7392 validation loss: 0.09407646
# EPOCH 45.0
#  train accuracy:0.7259455train loss: 0.09527244
#  ********* validation accuracy:0.7406 validation loss: 0.09326701
# EPOCH 46.0
#  train accuracy:0.7268364train loss: 0.09450417
#  ********* validation accuracy:0.741 validation loss: 0.092485525
# EPOCH 47.0
#  train accuracy:0.7276545train loss: 0.09376236
#  ********* validation accuracy:0.7414 validation loss: 0.09173055
# EPOCH 48.0
#  train accuracy:0.7285636train loss: 0.09304564
#  ********* validation accuracy:0.7422 validation loss: 0.09100074
# EPOCH 49.0
#  train accuracy:0.7293818train loss: 0.092352815
#  ********* validation accuracy:0.7432 validation loss: 0.09029486
# EPOCH 50.0
#  train accuracy:0.73005456train loss: 0.09168267
#  ********* validation accuracy:0.744 validation loss: 0.08961174
# EPOCH 51.0
#  train accuracy:0.73094547train loss: 0.091034144
#  ********* validation accuracy:0.7448 validation loss: 0.088950254
# EPOCH 52.0
#  train accuracy:0.73145455train loss: 0.09040621
#  ********* validation accuracy:0.7452 validation loss: 0.08830942
# EPOCH 53.0
#  train accuracy:0.73203635train loss: 0.08979786
#  ********* validation accuracy:0.7454 validation loss: 0.087688185
# EPOCH 54.0
#  train accuracy:0.7326546train loss: 0.08920821
#  ********* validation accuracy:0.7456 validation loss: 0.0870857
# EPOCH 55.0
#  train accuracy:0.7334909train loss: 0.08863642
#  ********* validation accuracy:0.746 validation loss: 0.08650109
# EPOCH 56.0
#  train accuracy:0.734train loss: 0.08808169
#  ********* validation accuracy:0.7462 validation loss: 0.085933544
# EPOCH 57.0
#  train accuracy:0.7350182train loss: 0.087543234
#  ********* validation accuracy:0.7464 validation loss: 0.085382305
# EPOCH 58.0
#  train accuracy:0.73554546train loss: 0.087020345
#  ********* validation accuracy:0.7464 validation loss: 0.08484665
# EPOCH 59.0
#  train accuracy:0.7360727train loss: 0.08651236
#  ********* validation accuracy:0.7464 validation loss: 0.08432591
# EPOCH 60.0
#  train accuracy:0.73652726train loss: 0.086018644
#  ********* validation accuracy:0.7474 validation loss: 0.083819464
# EPOCH 61.0
#  train accuracy:0.7371455train loss: 0.08553858
#  ********* validation accuracy:0.748 validation loss: 0.08332667
# EPOCH 62.0
#  train accuracy:0.73785454train loss: 0.0850716
#  ********* validation accuracy:0.7488 validation loss: 0.082846984
# EPOCH 63.0
#  train accuracy:0.73832726train loss: 0.08461717
#  ********* validation accuracy:0.7498 validation loss: 0.08237983
# EPOCH 64.0
#  train accuracy:0.73883635train loss: 0.08417475
#  ********* validation accuracy:0.7498 validation loss: 0.081924714
# EPOCH 65.0
#  train accuracy:0.7392train loss: 0.08374388
#  ********* validation accuracy:0.7496 validation loss: 0.08148116
# EPOCH 66.0
#  train accuracy:0.73963636train loss: 0.083324105
#  ********* validation accuracy:0.7512 validation loss: 0.081048705
# EPOCH 67.0
#  train accuracy:0.7401636train loss: 0.082914956
#  ********* validation accuracy:0.753 validation loss: 0.08062688
# EPOCH 68.0
#  train accuracy:0.7406727train loss: 0.08251607
#  ********* validation accuracy:0.7536 validation loss: 0.08021532
# EPOCH 69.0
#  train accuracy:0.7412909train loss: 0.08212701
#  ********* validation accuracy:0.7532 validation loss: 0.07981359
# EPOCH 70.0
#  train accuracy:0.7419636train loss: 0.08174742
#  ********* validation accuracy:0.7536 validation loss: 0.07942136
# EPOCH 71.0
#  train accuracy:0.7424train loss: 0.08137692
#  ********* validation accuracy:0.7542 validation loss: 0.079038195
# EPOCH 72.0
#  train accuracy:0.7431818train loss: 0.08101519
#  ********* validation accuracy:0.7546 validation loss: 0.078663826
# EPOCH 73.0
#  train accuracy:0.7436909train loss: 0.08066191
#  ********* validation accuracy:0.7552 validation loss: 0.078297906
# EPOCH 74.0
#  train accuracy:0.74447274train loss: 0.08031677
#  ********* validation accuracy:0.7556 validation loss: 0.07794013
# EPOCH 75.0
#  train accuracy:0.7449273train loss: 0.079979464
#  ********* validation accuracy:0.7558 validation loss: 0.0775902
# EPOCH 76.0
#  train accuracy:0.7451091train loss: 0.0796497
#  ********* validation accuracy:0.7566 validation loss: 0.07724782
# EPOCH 77.0
#  train accuracy:0.74554545train loss: 0.07932725
#  ********* validation accuracy:0.758 validation loss: 0.076912746
# EPOCH 78.0
#  train accuracy:0.7459818train loss: 0.079011835
#  ********* validation accuracy:0.7584 validation loss: 0.07658472
# EPOCH 79.0
#  train accuracy:0.7462909train loss: 0.07870322
#  ********* validation accuracy:0.759 validation loss: 0.0762635
# EPOCH 80.0
#  train accuracy:0.74701816train loss: 0.07840115
#  ********* validation accuracy:0.7594 validation loss: 0.07594885
# EPOCH 81.0
#  train accuracy:0.74734545train loss: 0.078105435
#  ********* validation accuracy:0.76 validation loss: 0.07564053
# EPOCH 82.0
#  train accuracy:0.7478909train loss: 0.077815846
#  ********* validation accuracy:0.7604 validation loss: 0.07533836
# EPOCH 83.0
#  train accuracy:0.74832726train loss: 0.07753217
#  ********* validation accuracy:0.7612 validation loss: 0.075042106
# EPOCH 84.0
#  train accuracy:0.7486909train loss: 0.077254236
#  ********* validation accuracy:0.7606 validation loss: 0.07475161
# EPOCH 85.0
#  train accuracy:0.74907273train loss: 0.07698184
#  ********* validation accuracy:0.7614 validation loss: 0.07446665
# EPOCH 86.0
#  train accuracy:0.7495091train loss: 0.0767148
#  ********* validation accuracy:0.7616 validation loss: 0.07418707
# EPOCH 87.0
#  train accuracy:0.7499091train loss: 0.07645297
#  ********* validation accuracy:0.7618 validation loss: 0.073912695
# EPOCH 88.0
#  train accuracy:0.7503273train loss: 0.07619614
#  ********* validation accuracy:0.7626 validation loss: 0.07364334
# EPOCH 89.0
#  train accuracy:0.7509636train loss: 0.07594419
#  ********* validation accuracy:0.7628 validation loss: 0.073378876
# EPOCH 90.0
#  train accuracy:0.7514909train loss: 0.07569696
#  ********* validation accuracy:0.764 validation loss: 0.07311915
# EPOCH 91.0
#  train accuracy:0.7518182train loss: 0.075454295
#  ********* validation accuracy:0.7642 validation loss: 0.07286399
# EPOCH 92.0
#  train accuracy:0.7522727train loss: 0.07521605
#  ********* validation accuracy:0.7648 validation loss: 0.07261327
# EPOCH 93.0
#  train accuracy:0.75274545train loss: 0.0749821
#  ********* validation accuracy:0.7658 validation loss: 0.07236685
# EPOCH 94.0
#  train accuracy:0.7530364train loss: 0.074752316
#  ********* validation accuracy:0.7662 validation loss: 0.07212462
# EPOCH 95.0
#  train accuracy:0.75334543train loss: 0.0745266
#  ********* validation accuracy:0.7668 validation loss: 0.07188644
# EPOCH 96.0
#  train accuracy:0.7535818train loss: 0.07430481
#  ********* validation accuracy:0.7678 validation loss: 0.07165222
# EPOCH 97.0
#  train accuracy:0.75403637train loss: 0.074086815
#  ********* validation accuracy:0.7682 validation loss: 0.07142182
# EPOCH 98.0
#  train accuracy:0.7545636train loss: 0.07387254
#  ********* validation accuracy:0.7682 validation loss: 0.071195126
# EPOCH 99.0
#  train accuracy:0.75496364train loss: 0.073661864
#  ********* validation accuracy:0.7686 validation loss: 0.07097206
# EPOCH 100.0
#  train accuracy:0.75543636train loss: 0.073454656
#  ********* validation accuracy:0.7686 validation loss: 0.07075248

# %%
plot_history(history)

# %%
a_test, c_test  = sess.run([accuracy, cross_entropy], feed_dict={X: x_test, y: y_test})

print('Test accuracy is: ', ("%.2f"%(a_test*100))+'%')
# Out:
# Test accuracy is:  75.02%

# %%
sess.close()

# %% [markdown]
# You can try increasing the number of epochs for better accuracy

# %% [markdown]
# # You are to build the computational graph by completing the required code statement with None assigned

# %% [markdown]
# ## 5. Build a five layer neural network with sigmoid activation

# %%
#Create computational graph

# input 
X = tf.placeholder(tf.float32, [None,784])
# labels (onehot encoded)
y = tf.placeholder(tf.float32, [None, 10])

''' First hidden layer with 200 neurons'''
# weights 1
W1 = tf.Variable(tf.truncated_normal([784, 200], stddev=0.1))
# biases 1
b1 = tf.Variable(tf.zeros([200]))

# weigthed sum
z1 = tf.matmul(X, W1) + b1

#  activation
h1 = tf.nn.sigmoid(z1)

''' Second hidden layer with 100 neurons'''
################## START CODE #########################
# weights 2
W2 = tf.Variable(tf.truncated_normal([200,100] , stddev = 0.1))
# biases 2
b2 = tf.Variable(tf.zeros([100]))

# weigthed sum
z2 = tf.matmul(h1, W2) + b2

#  activation
h2 = tf.nn.sigmoid(z2)

####################### END #############################

''' third Layer with 60 neurons'''
##################### START CODE #########################
# weights 3
W3 = tf.Variable(tf.truncated_normal([100,60] , stddev = 0.1))
# biases 3
b3 = tf.Variable(tf.zeros([60]))

# weigthed sum
z3 = tf.matmul(h2,W3) + b3
#  activation
h3 = tf.nn.sigmoid(z3)

#################### END ##################################

''' fourth Layer with 30 neurons'''
##################### START CODE #########################
# weights 4
W4 = tf.Variable(tf.truncated_normal([60,30] , stddev = 0.1))
# biases 4
b4 = tf.Variable(tf.zeros([30]))

# weigthed sum
z4 = tf.matmul(h3,W4) + b4


#  activation
h4 = tf.nn.sigmoid(z4)

#################### END ##################################

''' fifth/output Layer with 10 neurons'''
##################### START CODE #########################
# weights 5
W5 = tf.Variable(tf.truncated_normal([30,10] , stddev = 0.1))
# biases 5
b5 = tf.Variable(tf.zeros([10]))
# weigthed sum
z5 = tf.matmul(h4,W5) + b5

# softmax activation (optional)
h5 = tf.nn.softmax(z5)

#################### END ##################################



# cross-entropy loss function (= -sum(y_i * log(hi)) )
# TensorFlow provides the softmax_cross_entropy_with_logits function to avoid numerical stability
# problems with log(0) which is NaN
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=z5, labels=y)
cross_entropy = tf.reduce_mean(cross_entropy)

################### END ###############################

# accuracy of the trained model, between 0 (worst) and 1 (best)
correct_prediction = tf.equal(tf.argmax(h5, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# training
################# START CODE ########################
# learning rate
lr =0.03
train_step = tf.train.GradientDescentOptimizer(lr).minimize(cross_entropy)

################# END ###############################

# %% [markdown]
# Start a session

# %%
#Start session

# initialize all variables
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %% [markdown]
# Train & visualize train/val loss and accuracy

# %%
history = training(x_train, y_train, x_val, y_val, sess, epochs=100)
# Out:
# EPOCH 1.0
#  train accuracy:0.09898182train loss: 2.3039036
#  ********* validation accuracy:0.1112 validation loss: 2.301516
# EPOCH 2.0
#  train accuracy:0.09898182train loss: 2.3037236
#  ********* validation accuracy:0.1112 validation loss: 2.301332
# EPOCH 3.0
#  train accuracy:0.09898182train loss: 2.3035436
#  ********* validation accuracy:0.1112 validation loss: 2.301148
# EPOCH 4.0
#  train accuracy:0.09898182train loss: 2.3033574
#  ********* validation accuracy:0.1112 validation loss: 2.300958
# EPOCH 5.0
#  train accuracy:0.09898182train loss: 2.3031583
#  ********* validation accuracy:0.1112 validation loss: 2.3007543
# EPOCH 6.0
#  train accuracy:0.09898182train loss: 2.3029387
#  ********* validation accuracy:0.1112 validation loss: 2.3005292
# EPOCH 7.0
#  train accuracy:0.09898182train loss: 2.3026888
#  ********* validation accuracy:0.1112 validation loss: 2.3002737
# EPOCH 8.0
#  train accuracy:0.09898182train loss: 2.3023958
#  ********* validation accuracy:0.1112 validation loss: 2.2999737
# EPOCH 9.0
#  train accuracy:0.09898182train loss: 2.3020422
#  ********* validation accuracy:0.1112 validation loss: 2.2996118
# EPOCH 10.0
#  train accuracy:0.09898182train loss: 2.3016016
#  ********* validation accuracy:0.1112 validation loss: 2.299161
# EPOCH 11.0
#  train accuracy:0.09898182train loss: 2.3010337
#  ********* validation accuracy:0.1112 validation loss: 2.2985804
# EPOCH 12.0
#  train accuracy:0.09898182train loss: 2.3002746
#  ********* validation accuracy:0.1112 validation loss: 2.2978044
# EPOCH 13.0
#  train accuracy:0.09898182train loss: 2.2992132
#  ********* validation accuracy:0.1112 validation loss: 2.2967196
# EPOCH 14.0
#  train accuracy:0.09898182train loss: 2.2976444
#  ********* validation accuracy:0.1112 validation loss: 2.295119
# EPOCH 15.0
#  train accuracy:0.09898182train loss: 2.295152
#  ********* validation accuracy:0.1112 validation loss: 2.2925794
# EPOCH 16.0
#  train accuracy:0.09898182train loss: 2.2907655
#  ********* validation accuracy:0.1112 validation loss: 2.2881188
# EPOCH 17.0
#  train accuracy:0.09898182train loss: 2.2817063
#  ********* validation accuracy:0.1112 validation loss: 2.27893
# EPOCH 18.0
#  train accuracy:0.20518182train loss: 2.2568202
#  ********* validation accuracy:0.2176 validation loss: 2.2537785
# EPOCH 19.0
#  train accuracy:0.3557091train loss: 2.1409812
#  ********* validation accuracy:0.3758 validation loss: 2.1371477
# EPOCH 20.0
#  train accuracy:0.3585091train loss: 1.799789
#  ********* validation accuracy:0.3714 validation loss: 1.7943928
# EPOCH 21.0
#  train accuracy:0.4091818train loss: 1.6445292
#  ********* validation accuracy:0.4206 validation loss: 1.6381
# EPOCH 22.0
#  train accuracy:0.46518183train loss: 1.4797221
#  ********* validation accuracy:0.4792 validation loss: 1.4693745
# EPOCH 23.0
#  train accuracy:0.5376727train loss: 1.2822646
#  ********* validation accuracy:0.5444 validation loss: 1.2694856
# EPOCH 24.0
#  train accuracy:0.5564909train loss: 1.1727082
#  ********* validation accuracy:0.5584 validation loss: 1.1601641
# EPOCH 25.0
#  train accuracy:0.5797091train loss: 1.0977092
#  ********* validation accuracy:0.5812 validation loss: 1.0846131
# EPOCH 26.0
#  train accuracy:0.60496366train loss: 1.0390449
#  ********* validation accuracy:0.6098 validation loss: 1.0249964
# EPOCH 27.0
#  train accuracy:0.62676364train loss: 0.989224
#  ********* validation accuracy:0.6358 validation loss: 0.9737245
# EPOCH 28.0
#  train accuracy:0.6413818train loss: 0.94815284
#  ********* validation accuracy:0.6526 validation loss: 0.93053085
# EPOCH 29.0
#  train accuracy:0.6512182train loss: 0.9150162
#  ********* validation accuracy:0.663 validation loss: 0.8947214
# EPOCH 30.0
#  train accuracy:0.6616909train loss: 0.88734746
#  ********* validation accuracy:0.6786 validation loss: 0.8640276
# EPOCH 31.0
#  train accuracy:0.6782182train loss: 0.8632246
#  ********* validation accuracy:0.6998 validation loss: 0.83662814
# EPOCH 32.0
#  train accuracy:0.69525456train loss: 0.84153223
#  ********* validation accuracy:0.7138 validation loss: 0.8114318
# EPOCH 33.0
#  train accuracy:0.7076727train loss: 0.8216332
#  ********* validation accuracy:0.731 validation loss: 0.78779936
# EPOCH 34.0
#  train accuracy:0.7167091train loss: 0.8031494
#  ********* validation accuracy:0.741 validation loss: 0.7653432
# EPOCH 35.0
#  train accuracy:0.7241273train loss: 0.78591484
#  ********* validation accuracy:0.747 validation loss: 0.74386364
# EPOCH 36.0
#  train accuracy:0.7295273train loss: 0.7699531
#  ********* validation accuracy:0.7548 validation loss: 0.72332865
# EPOCH 37.0
#  train accuracy:0.73463637train loss: 0.75536746
#  ********* validation accuracy:0.7596 validation loss: 0.70380664
# EPOCH 38.0
#  train accuracy:0.7393091train loss: 0.7421845
#  ********* validation accuracy:0.7678 validation loss: 0.68535614
# EPOCH 39.0
#  train accuracy:0.7426train loss: 0.73028195
#  ********* validation accuracy:0.774 validation loss: 0.66793036
# EPOCH 40.0
#  train accuracy:0.7459273train loss: 0.71945614
#  ********* validation accuracy:0.7766 validation loss: 0.6513975
# EPOCH 41.0
#  train accuracy:0.7486909train loss: 0.70950514
#  ********* validation accuracy:0.7814 validation loss: 0.6356377
# EPOCH 42.0
#  train accuracy:0.7520364train loss: 0.70026696
#  ********* validation accuracy:0.7864 validation loss: 0.6205899
# EPOCH 43.0
#  train accuracy:0.75503635train loss: 0.6916447
#  ********* validation accuracy:0.791 validation loss: 0.606176
# EPOCH 44.0
#  train accuracy:0.7574546train loss: 0.6835908
#  ********* validation accuracy:0.7976 validation loss: 0.59228194
# EPOCH 45.0
#  train accuracy:0.7594909train loss: 0.6760754
#  ********* validation accuracy:0.8006 validation loss: 0.5788078
# EPOCH 46.0
#  train accuracy:0.7617091train loss: 0.66907626
#  ********* validation accuracy:0.8038 validation loss: 0.5656768
# EPOCH 47.0
#  train accuracy:0.7634909train loss: 0.662575
#  ********* validation accuracy:0.8072 validation loss: 0.55282736
# EPOCH 48.0
#  train accuracy:0.76501817train loss: 0.65655553
#  ********* validation accuracy:0.8104 validation loss: 0.540207
# EPOCH 49.0
#  train accuracy:0.7666train loss: 0.65100014
#  ********* validation accuracy:0.8138 validation loss: 0.52777493
# EPOCH 50.0
#  train accuracy:0.7683455train loss: 0.64588857
#  ********* validation accuracy:0.8182 validation loss: 0.515511
# EPOCH 51.0
#  train accuracy:0.7702182train loss: 0.6412
#  ********* validation accuracy:0.8222 validation loss: 0.5034177
# EPOCH 52.0
#  train accuracy:0.7715091train loss: 0.6369187
#  ********* validation accuracy:0.8256 validation loss: 0.49150342
# EPOCH 53.0
#  train accuracy:0.7728train loss: 0.63302034
#  ********* validation accuracy:0.8288 validation loss: 0.4797702
# EPOCH 54.0
#  train accuracy:0.7739273train loss: 0.6294638
#  ********* validation accuracy:0.832 validation loss: 0.46822554
# EPOCH 55.0
#  train accuracy:0.77494544train loss: 0.62622434
#  ********* validation accuracy:0.8348 validation loss: 0.4568624
# EPOCH 56.0
#  train accuracy:0.7758727train loss: 0.62331307
#  ********* validation accuracy:0.8386 validation loss: 0.4456247
# EPOCH 57.0
#  train accuracy:0.77714545train loss: 0.6207696
#  ********* validation accuracy:0.843 validation loss: 0.43440524
# EPOCH 58.0
#  train accuracy:0.7776909train loss: 0.6186442
#  ********* validation accuracy:0.8478 validation loss: 0.42305738
# EPOCH 59.0
#  train accuracy:0.77869093train loss: 0.61688167
#  ********* validation accuracy:0.8532 validation loss: 0.41151378
# EPOCH 60.0
#  train accuracy:0.7797818train loss: 0.61535525
#  ********* validation accuracy:0.857 validation loss: 0.3999217
# EPOCH 61.0
#  train accuracy:0.78214544train loss: 0.61413443
#  ********* validation accuracy:0.8634 validation loss: 0.38836345
# EPOCH 62.0
#  train accuracy:0.78374547train loss: 0.6132448
#  ********* validation accuracy:0.8694 validation loss: 0.3768704
# EPOCH 63.0
#  train accuracy:0.7859091train loss: 0.6127039
#  ********* validation accuracy:0.8724 validation loss: 0.3654509
# EPOCH 64.0
#  train accuracy:0.788train loss: 0.6125553
#  ********* validation accuracy:0.8782 validation loss: 0.35408804
# EPOCH 65.0
#  train accuracy:0.7897636train loss: 0.6127932
#  ********* validation accuracy:0.885 validation loss: 0.3428093
# EPOCH 66.0
#  train accuracy:0.79147273train loss: 0.6133753
#  ********* validation accuracy:0.8886 validation loss: 0.3316987
# EPOCH 67.0
#  train accuracy:0.7922909train loss: 0.61425215
#  ********* validation accuracy:0.894 validation loss: 0.32088578
# EPOCH 68.0
#  train accuracy:0.7943091train loss: 0.6154798
#  ********* validation accuracy:0.8988 validation loss: 0.3103974
# EPOCH 69.0
#  train accuracy:0.7955273train loss: 0.61718565
#  ********* validation accuracy:0.905 validation loss: 0.30014488
# EPOCH 70.0
#  train accuracy:0.79638183train loss: 0.61946034
#  ********* validation accuracy:0.908 validation loss: 0.29003048
# EPOCH 71.0
#  train accuracy:0.79365456train loss: 0.6289023
#  ********* validation accuracy:0.9048 validation loss: 0.28938362
# EPOCH 72.0
#  train accuracy:0.7942727train loss: 0.6306888
#  ********* validation accuracy:0.9076 validation loss: 0.28062043
# EPOCH 73.0
#  train accuracy:0.79394543train loss: 0.63420063
#  ********* validation accuracy:0.9098 validation loss: 0.273776
# EPOCH 74.0
#  train accuracy:0.79441816train loss: 0.63749987
#  ********* validation accuracy:0.9116 validation loss: 0.26677704
# EPOCH 75.0
#  train accuracy:0.7952train loss: 0.6407916
#  ********* validation accuracy:0.9142 validation loss: 0.2598065
# EPOCH 76.0
#  train accuracy:0.79563636train loss: 0.64414704
#  ********* validation accuracy:0.9174 validation loss: 0.25289392
# EPOCH 77.0
#  train accuracy:0.79596364train loss: 0.64760023
#  ********* validation accuracy:0.9202 validation loss: 0.24603084
# EPOCH 78.0
#  train accuracy:0.7963455train loss: 0.65130097
#  ********* validation accuracy:0.9222 validation loss: 0.23935796
# EPOCH 79.0
#  train accuracy:0.8019818train loss: 0.6420628
#  ********* validation accuracy:0.9318 validation loss: 0.21940862
# EPOCH 80.0
#  train accuracy:0.79983634train loss: 0.6637673
#  ********* validation accuracy:0.9256 validation loss: 0.2297597
# EPOCH 81.0
#  train accuracy:0.80474544train loss: 0.644348
#  ********* validation accuracy:0.936 validation loss: 0.204854
# EPOCH 82.0
#  train accuracy:0.79945457train loss: 0.67539775
#  ********* validation accuracy:0.928 validation loss: 0.21973237
# EPOCH 83.0
#  train accuracy:0.80472726train loss: 0.64881337
#  ********* validation accuracy:0.942 validation loss: 0.19219618
# EPOCH 84.0
#  train accuracy:0.80512726train loss: 0.6533701
#  ********* validation accuracy:0.9442 validation loss: 0.18494757
# EPOCH 85.0
#  train accuracy:0.80605453train loss: 0.654852
#  ********* validation accuracy:0.9456 validation loss: 0.17914447
# EPOCH 86.0
#  train accuracy:0.8072182train loss: 0.6564757
#  ********* validation accuracy:0.9474 validation loss: 0.17597915
# EPOCH 87.0
#  train accuracy:0.8047636train loss: 0.6723818
#  ********* validation accuracy:0.9456 validation loss: 0.17686903
# EPOCH 88.0
#  train accuracy:0.8084546train loss: 0.66122264
#  ********* validation accuracy:0.953 validation loss: 0.16298588
# EPOCH 89.0
#  train accuracy:0.8092727train loss: 0.6656693
#  ********* validation accuracy:0.9544 validation loss: 0.15873256
# EPOCH 90.0
#  train accuracy:0.8088545train loss: 0.66713387
#  ********* validation accuracy:0.957 validation loss: 0.15296015
# EPOCH 91.0
#  train accuracy:0.8082727train loss: 0.6740392
#  ********* validation accuracy:0.9602 validation loss: 0.14766034
# EPOCH 92.0
#  train accuracy:0.8086909train loss: 0.67687833
#  ********* validation accuracy:0.9634 validation loss: 0.14267221
# EPOCH 93.0
#  train accuracy:0.8074train loss: 0.69349813
#  ********* validation accuracy:0.943 validation loss: 0.17218804
# EPOCH 94.0
#  train accuracy:0.80865455train loss: 0.685587
#  ********* validation accuracy:0.9664 validation loss: 0.13334864
# EPOCH 95.0
#  train accuracy:0.8095091train loss: 0.6910511
#  ********* validation accuracy:0.9648 validation loss: 0.13261937
# EPOCH 96.0
#  train accuracy:0.7959273train loss: 0.73867345
#  ********* validation accuracy:0.9422 validation loss: 0.17191155
# EPOCH 97.0
#  train accuracy:0.8078909train loss: 0.7017776
#  ********* validation accuracy:0.9704 validation loss: 0.12363989
# EPOCH 98.0
#  train accuracy:0.8097091train loss: 0.70349586
#  ********* validation accuracy:0.9736 validation loss: 0.11589909
# EPOCH 99.0
#  train accuracy:0.8092545train loss: 0.710892
#  ********* validation accuracy:0.9754 validation loss: 0.111046396
# EPOCH 100.0
#  train accuracy:0.80972725train loss: 0.7126214
#  ********* validation accuracy:0.977 validation loss: 0.10729845

# %%
plot_history(history)

# %% [markdown]
# Test accuracy

# %%
a_test, c_test  = sess.run([accuracy, cross_entropy], feed_dict={X: x_test, y: y_test})

print('Test accuracy is: ', ("%.2f"%(a_test*100))+'%')
# Out:
# Test accuracy is:  80.44%

# %% [markdown]
# ## 6. Replace the sigmoid activations with relu

# %% [markdown]
# Computational graph

# %%
#Create computational graph

# input 
X = tf.placeholder(tf.float32, [None,784])
# labels (onehot encoded)
y = tf.placeholder(tf.float32, [None, 10])

''' First hidden layer with 200 neurons'''
################## START CODE #########################
# weights 1
W1 = tf.Variable(tf.truncated_normal([784,200] , stddev = 0.1))
# biases 1
b1 = tf.Variable(tf.zeros([200]))

# weigthed sum
z1 = tf.matmul(X,W1) + b1

#  activation
h1 = tf.nn.relu(z1)
####################### END #############################

''' Second hidden layer with 100 neurons'''
################## START CODE #########################
# weights 2
W2 = tf.Variable(tf.truncated_normal([200,100] , stddev = 0.1))
# biases 2
b2 = tf.Variable(tf.zeros([100]))

# weigthed sum
z2 = tf.matmul(h1,W2) + b2

# activation
h2 = tf.nn.relu(z2)

####################### END #############################

''' third Layer with 60 neurons'''
##################### START CODE #########################
# weights 3
W3 = tf.Variable(tf.truncated_normal([100, 60], stddev=0.1))
# biases 3
b3 =tf.Variable(tf.zeros([60]))

# weigthed sum
z3 = tf.matmul(h2, W3) + b3

# activation
h3 = tf.nn.relu(z3)

#################### END ##################################

''' fourth Layer with 30 neurons'''
##################### START CODE #########################
# weights 4
W4 = tf.Variable(tf.truncated_normal([60,30] , stddev = 0.1))
# biases 4
b4 = tf.Variable(tf.zeros([30]))

# weigthed sum
z4 = tf.matmul(h3,W4) + b4

# activation 
h4 = tf.nn.relu(z4)

#################### END ##################################

''' fifth/output Layer with 10 neurons'''
##################### START CODE #########################
# weights 5
W5 = tf.Variable(tf.truncated_normal([30,10] , stddev = 0.1))
# biases 5
b5 = tf.Variable(tf.zeros([10]))
# weigthed sum
z5 = tf.matmul(h4,W5) + b5

# softmax activation (optional)
h5 = tf.nn.softmax(z5)

#################### END ##################################



# cross-entropy loss function (= -sum(yi * log(hi)) )
# TensorFlow provides the softmax_cross_entropy_with_logits function to avoid numerical stability
# problems with log(0) which is NaN
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=z5, labels=y)
cross_entropy = tf.reduce_mean(cross_entropy)

################### END ###############################

# accuracy of the trained model, between 0 (worst) and 1 (best)
correct_prediction = tf.equal(tf.argmax(h5, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# training
################# START CODE ########################
# learning rate
lr = 0.03
train_step = tf.train.GradientDescentOptimizer(lr).minimize(cross_entropy)

################# END ###############################

# %% [markdown]
# Start a session

# %%
#Start session

# initialize all variables
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %% [markdown]
# Train & visualize train/val loss and accuracy

# %%
history = training(x_train, y_train, x_val, y_val, sess, epochs=100)
# Out:
# EPOCH 1.0
#  train accuracy:0.7494182train loss: 0.6707039
#  ********* validation accuracy:0.7704 validation loss: 0.62567663
# EPOCH 2.0
#  train accuracy:0.81332725train loss: 0.53937536
#  ********* validation accuracy:0.8546 validation loss: 0.43704987
# EPOCH 3.0
#  train accuracy:0.8243818train loss: 0.50552756
#  ********* validation accuracy:0.8788 validation loss: 0.35001415
# EPOCH 4.0
#  train accuracy:0.82774544train loss: 0.5208271
#  ********* validation accuracy:0.8922 validation loss: 0.31018692
# EPOCH 5.0
#  train accuracy:0.8300909train loss: 0.49885952
#  ********* validation accuracy:0.8986 validation loss: 0.3462658
# EPOCH 6.0
#  train accuracy:0.8266364train loss: 0.57544696
#  ********* validation accuracy:0.9186 validation loss: 0.2342856
# EPOCH 7.0
#  train accuracy:0.823train loss: 0.5855682
#  ********* validation accuracy:0.9364 validation loss: 0.18999505
# EPOCH 8.0
#  train accuracy:0.79963636train loss: 0.81175524
#  ********* validation accuracy:0.8902 validation loss: 0.3395183
# EPOCH 9.0
#  train accuracy:0.8364546train loss: 0.5776687
#  ********* validation accuracy:0.9732 validation loss: 0.10424778
# EPOCH 10.0
#  train accuracy:0.8159818train loss: 0.7483294
#  ********* validation accuracy:0.947 validation loss: 0.14289123
# EPOCH 11.0
#  train accuracy:0.83901817train loss: 0.65774035
#  ********* validation accuracy:0.9904 validation loss: 0.046038993
# EPOCH 12.0
#  train accuracy:0.8383818train loss: 0.7261831
#  ********* validation accuracy:0.9952 validation loss: 0.029503236
# EPOCH 13.0
#  train accuracy:0.8380182train loss: 0.7432236
#  ********* validation accuracy:0.9974 validation loss: 0.02375631
# EPOCH 14.0
#  train accuracy:0.8370909train loss: 0.85880286
#  ********* validation accuracy:0.9994 validation loss: 0.012190604
# EPOCH 15.0
#  train accuracy:0.8359636train loss: 0.9240449
#  ********* validation accuracy:0.9996 validation loss: 0.008305277
# EPOCH 16.0
#  train accuracy:0.8352909train loss: 0.9791957
#  ********* validation accuracy:0.9996 validation loss: 0.0058374945
# EPOCH 17.0
#  train accuracy:0.8348train loss: 1.0262692
#  ********* validation accuracy:1.0 validation loss: 0.0041715833
# EPOCH 18.0
#  train accuracy:0.8344train loss: 1.0669744
#  ********* validation accuracy:1.0 validation loss: 0.00317432
# EPOCH 19.0
#  train accuracy:0.8342909train loss: 1.1020416
#  ********* validation accuracy:1.0 validation loss: 0.0025271615
# EPOCH 20.0
#  train accuracy:0.83403635train loss: 1.1326396
#  ********* validation accuracy:1.0 validation loss: 0.0020793977
# EPOCH 21.0
#  train accuracy:0.8339818train loss: 1.1593096
#  ********* validation accuracy:1.0 validation loss: 0.0017556736
# EPOCH 22.0
#  train accuracy:0.8338train loss: 1.1833329
#  ********* validation accuracy:1.0 validation loss: 0.0015116881
# EPOCH 23.0
#  train accuracy:0.83376366train loss: 1.204915
#  ********* validation accuracy:1.0 validation loss: 0.0013211626
# EPOCH 24.0
#  train accuracy:0.83385456train loss: 1.2245392
#  ********* validation accuracy:1.0 validation loss: 0.001167884
# EPOCH 25.0
#  train accuracy:0.8338train loss: 1.2424594
#  ********* validation accuracy:1.0 validation loss: 0.0010438326
# EPOCH 26.0
#  train accuracy:0.83376366train loss: 1.2590026
#  ********* validation accuracy:1.0 validation loss: 0.00094153825
# EPOCH 27.0
#  train accuracy:0.83376366train loss: 1.2743824
#  ********* validation accuracy:1.0 validation loss: 0.0008553848
# EPOCH 28.0
#  train accuracy:0.8338train loss: 1.2888284
#  ********* validation accuracy:1.0 validation loss: 0.0007821212
# EPOCH 29.0
#  train accuracy:0.83378184train loss: 1.302433
#  ********* validation accuracy:1.0 validation loss: 0.00071923644
# EPOCH 30.0
#  train accuracy:0.83370906train loss: 1.3152086
#  ********* validation accuracy:1.0 validation loss: 0.00066482584
# EPOCH 31.0
#  train accuracy:0.83387274train loss: 1.3272485
#  ********* validation accuracy:1.0 validation loss: 0.00061727717
# EPOCH 32.0
#  train accuracy:0.8339273train loss: 1.3387116
#  ********* validation accuracy:1.0 validation loss: 0.0005754546
# EPOCH 33.0
#  train accuracy:0.83387274train loss: 1.3495991
#  ********* validation accuracy:1.0 validation loss: 0.00053838966
# EPOCH 34.0
#  train accuracy:0.83385456train loss: 1.3599247
#  ********* validation accuracy:1.0 validation loss: 0.00050539616
# EPOCH 35.0
#  train accuracy:0.8339091train loss: 1.3697389
#  ********* validation accuracy:1.0 validation loss: 0.00047585613
# EPOCH 36.0
#  train accuracy:0.8338909train loss: 1.379094
#  ********* validation accuracy:1.0 validation loss: 0.00044928023
# EPOCH 37.0
#  train accuracy:0.8338364train loss: 1.3880358
#  ********* validation accuracy:1.0 validation loss: 0.0004252606
# EPOCH 38.0
#  train accuracy:0.8338364train loss: 1.3966076
#  ********* validation accuracy:1.0 validation loss: 0.00040344396
# EPOCH 39.0
#  train accuracy:0.83385456train loss: 1.4048551
#  ********* validation accuracy:1.0 validation loss: 0.00038353156
# EPOCH 40.0
#  train accuracy:0.8338364train loss: 1.4128009
#  ********* validation accuracy:1.0 validation loss: 0.00036531602
# EPOCH 41.0
#  train accuracy:0.83370906train loss: 1.4205793
#  ********* validation accuracy:1.0 validation loss: 0.00034852794
# EPOCH 42.0
#  train accuracy:0.8336545train loss: 1.4281363
#  ********* validation accuracy:1.0 validation loss: 0.00033302308
# EPOCH 43.0
#  train accuracy:0.8336545train loss: 1.4354614
#  ********* validation accuracy:1.0 validation loss: 0.00031868092
# EPOCH 44.0
#  train accuracy:0.83370906train loss: 1.442498
#  ********* validation accuracy:1.0 validation loss: 0.0003054252
# EPOCH 45.0
#  train accuracy:0.8336909train loss: 1.449273
#  ********* validation accuracy:1.0 validation loss: 0.00029314347
# EPOCH 46.0
#  train accuracy:0.83363634train loss: 1.4558498
#  ********* validation accuracy:1.0 validation loss: 0.00028164577
# EPOCH 47.0
#  train accuracy:0.83361816train loss: 1.4622189
#  ********* validation accuracy:1.0 validation loss: 0.0002709374
# EPOCH 48.0
#  train accuracy:0.8336train loss: 1.4683971
#  ********* validation accuracy:1.0 validation loss: 0.00026095967
# EPOCH 49.0
#  train accuracy:0.83361816train loss: 1.4743837
#  ********* validation accuracy:1.0 validation loss: 0.00025163527
# EPOCH 50.0
#  train accuracy:0.8336train loss: 1.4802071
#  ********* validation accuracy:1.0 validation loss: 0.00024289128
# EPOCH 51.0
#  train accuracy:0.83354545train loss: 1.4858807
#  ********* validation accuracy:1.0 validation loss: 0.0002346786
# EPOCH 52.0
#  train accuracy:0.8335091train loss: 1.4914012
#  ********* validation accuracy:1.0 validation loss: 0.00022696212
# EPOCH 53.0
#  train accuracy:0.83354545train loss: 1.4967687
#  ********* validation accuracy:1.0 validation loss: 0.00021968785
# EPOCH 54.0
#  train accuracy:0.8334727train loss: 1.5020088
#  ********* validation accuracy:1.0 validation loss: 0.00021282921
# EPOCH 55.0
#  train accuracy:0.83343637train loss: 1.5070941
#  ********* validation accuracy:1.0 validation loss: 0.00020634575
# EPOCH 56.0
#  train accuracy:0.8334727train loss: 1.5120542
#  ********* validation accuracy:1.0 validation loss: 0.00020021692
# EPOCH 57.0
#  train accuracy:0.8334train loss: 1.5168898
#  ********* validation accuracy:1.0 validation loss: 0.00019440746
# EPOCH 58.0
#  train accuracy:0.83338183train loss: 1.5215988
#  ********* validation accuracy:1.0 validation loss: 0.00018890298
# EPOCH 59.0
#  train accuracy:0.8333455train loss: 1.5261956
#  ********* validation accuracy:1.0 validation loss: 0.00018367491
# EPOCH 60.0
#  train accuracy:0.83336365train loss: 1.5306892
#  ********* validation accuracy:1.0 validation loss: 0.00017870986
# EPOCH 61.0
#  train accuracy:0.8333455train loss: 1.5350894
#  ********* validation accuracy:1.0 validation loss: 0.00017397654
# EPOCH 62.0
#  train accuracy:0.8333273train loss: 1.5393989
#  ********* validation accuracy:1.0 validation loss: 0.00016946784
# EPOCH 63.0
#  train accuracy:0.83329093train loss: 1.5436082
#  ********* validation accuracy:1.0 validation loss: 0.0001651713
# EPOCH 64.0
#  train accuracy:0.83329093train loss: 1.5477309
#  ********* validation accuracy:1.0 validation loss: 0.00016106553
# EPOCH 65.0
#  train accuracy:0.83327276train loss: 1.5517746
#  ********* validation accuracy:1.0 validation loss: 0.0001571404
# EPOCH 66.0
#  train accuracy:0.83327276train loss: 1.5557332
#  ********* validation accuracy:1.0 validation loss: 0.0001533861
# EPOCH 67.0
#  train accuracy:0.8332545train loss: 1.5596068
#  ********* validation accuracy:1.0 validation loss: 0.00014979488
# EPOCH 68.0
#  train accuracy:0.8332545train loss: 1.5634181
#  ********* validation accuracy:1.0 validation loss: 0.00014635175
# EPOCH 69.0
#  train accuracy:0.83323634train loss: 1.5671543
#  ********* validation accuracy:1.0 validation loss: 0.00014305262
# EPOCH 70.0
#  train accuracy:0.8332545train loss: 1.5708232
#  ********* validation accuracy:1.0 validation loss: 0.00013988528
# EPOCH 71.0
#  train accuracy:0.8333091train loss: 1.5744524
#  ********* validation accuracy:1.0 validation loss: 0.00013683725
# EPOCH 72.0
#  train accuracy:0.83327276train loss: 1.5780166
#  ********* validation accuracy:1.0 validation loss: 0.00013390504
# EPOCH 73.0
#  train accuracy:0.8332545train loss: 1.5815233
#  ********* validation accuracy:1.0 validation loss: 0.00013108568
# EPOCH 74.0
#  train accuracy:0.8332545train loss: 1.5849715
#  ********* validation accuracy:1.0 validation loss: 0.00012837241
# EPOCH 75.0
#  train accuracy:0.83321816train loss: 1.5883614
#  ********* validation accuracy:1.0 validation loss: 0.00012575742
# EPOCH 76.0
#  train accuracy:0.83321816train loss: 1.5916955
#  ********* validation accuracy:1.0 validation loss: 0.00012324112
# EPOCH 77.0
#  train accuracy:0.83323634train loss: 1.5949799
#  ********* validation accuracy:1.0 validation loss: 0.00012081417
# EPOCH 78.0
#  train accuracy:0.83323634train loss: 1.5982077
#  ********* validation accuracy:1.0 validation loss: 0.000118473414
# EPOCH 79.0
#  train accuracy:0.83323634train loss: 1.601374
#  ********* validation accuracy:1.0 validation loss: 0.00011621442
# EPOCH 80.0
#  train accuracy:0.8332train loss: 1.6044935
#  ********* validation accuracy:1.0 validation loss: 0.00011403216
# EPOCH 81.0
#  train accuracy:0.8332train loss: 1.6075681
#  ********* validation accuracy:1.0 validation loss: 0.00011192273
# EPOCH 82.0
#  train accuracy:0.8331818train loss: 1.6105975
#  ********* validation accuracy:1.0 validation loss: 0.00010988124
# EPOCH 83.0
#  train accuracy:0.8332train loss: 1.6135826
#  ********* validation accuracy:1.0 validation loss: 0.000107909764
# EPOCH 84.0
#  train accuracy:0.8331636train loss: 1.6165204
#  ********* validation accuracy:1.0 validation loss: 0.000106003
# EPOCH 85.0
#  train accuracy:0.83314544train loss: 1.6194203
#  ********* validation accuracy:1.0 validation loss: 0.000104154584
# EPOCH 86.0
#  train accuracy:0.83314544train loss: 1.6222707
#  ********* validation accuracy:1.0 validation loss: 0.00010236511
# EPOCH 87.0
#  train accuracy:0.8331091train loss: 1.6250869
#  ********* validation accuracy:1.0 validation loss: 0.00010062928
# EPOCH 88.0
#  train accuracy:0.8330909train loss: 1.6278579
#  ********* validation accuracy:1.0 validation loss: 9.894605e-05
# EPOCH 89.0
#  train accuracy:0.83303636train loss: 1.6305915
#  ********* validation accuracy:1.0 validation loss: 9.731414e-05
# EPOCH 90.0
#  train accuracy:0.8330182train loss: 1.6332959
#  ********* validation accuracy:1.0 validation loss: 9.572862e-05
# EPOCH 91.0
#  train accuracy:0.8330182train loss: 1.6359608
#  ********* validation accuracy:1.0 validation loss: 9.41903e-05
# EPOCH 92.0
#  train accuracy:0.8330182train loss: 1.6385858
#  ********* validation accuracy:1.0 validation loss: 9.269712e-05
# EPOCH 93.0
#  train accuracy:0.8330182train loss: 1.6411772
#  ********* validation accuracy:1.0 validation loss: 9.124618e-05
# EPOCH 94.0
#  train accuracy:0.833train loss: 1.6437359
#  ********* validation accuracy:1.0 validation loss: 8.983642e-05
# EPOCH 95.0
#  train accuracy:0.8330182train loss: 1.6462592
#  ********* validation accuracy:1.0 validation loss: 8.846812e-05
# EPOCH 96.0
#  train accuracy:0.833train loss: 1.6487503
#  ********* validation accuracy:1.0 validation loss: 8.713692e-05
# EPOCH 97.0
#  train accuracy:0.8329818train loss: 1.6512094
#  ********* validation accuracy:1.0 validation loss: 8.584242e-05
# EPOCH 98.0
#  train accuracy:0.8329818train loss: 1.6536369
#  ********* validation accuracy:1.0 validation loss: 8.458289e-05
# EPOCH 99.0
#  train accuracy:0.83296365train loss: 1.656054
#  ********* validation accuracy:1.0 validation loss: 8.335509e-05
# EPOCH 100.0
#  train accuracy:0.83296365train loss: 1.6584429
#  ********* validation accuracy:1.0 validation loss: 8.215775e-05

# %%
plot_history(history)

# %% [markdown]
# Test Accuracy

# %%
a_test, c_test  = sess.run([accuracy, cross_entropy], feed_dict={X: x_test, y: y_test})

print('Test accuracy is: ', ("%.2f"%(a_test*100))+'%')
# Out:
# Test accuracy is:  82.17%

# %% [markdown]
# ## 7. Introduce learning rate decay

# %% [markdown]
# Computational graph

# %%
#Create computational graph

# input 
X = tf.placeholder(tf.float32, [None,784])
# labels (onehot encoded)
y = tf.placeholder(tf.float32, [None, 10])
# step for variable learning rate
step_val = tf.placeholder(tf.int32)

''' First hidden layer with 200 neurons'''
####################### START CODE #############################
# weights 1
W1 = tf.Variable(tf.truncated_normal([784, 200], stddev=0.1))
# biases 1
b1 = tf.Variable(tf.zeros([200]))

# weigthed sum
z1 = tf.matmul(X,W1) + b1

#  activation
h1 = tf.nn.relu(z1)
####################### END #############################

''' Second hidden layer with 100 neurons'''
################## START CODE #########################
# weights 2
W2 = tf.Variable(tf.truncated_normal([200,100] , stddev = 0.1))
# biases 2
b2 = tf.Variable(tf.zeros([100]))

# weigthed sum
z2 = tf.matmul(h1,W2) + b2
# activation
h2 = tf.nn.relu(z2)

####################### END #############################

''' third Layer with 60 neurons'''
##################### START CODE #########################
# weights 3
W3 = tf.Variable(tf.truncated_normal([100, 60], stddev=0.1))
# biases 3
b3 = tf.Variable(tf.zeros([60]))

# weigthed sum
z3 = tf.matmul(h2,W3) + b3

# activation
h3 = tf.nn.relu(z3)

#################### END ##################################

''' fourth Layer with 30 neurons'''
##################### START CODE #########################
# weights 4
W4 = tf.Variable(tf.truncated_normal([60,30] , stddev = 0.1))
# biases 4
b4 = tf.Variable(tf.zeros([30]))

# weigthed sum
z4 = tf.matmul(h3,W4) + b4

# activation 
h4 = tf.nn.relu(z4)

#################### END ##################################

''' fifth/output Layer with 10 neurons'''
##################### START CODE #########################
# weights 5
W5 = (tf.truncated_normal([30,10] , stddev = 0.1))
# biases 5
b5 = tf.Variable(tf.zeros([10]))
# weigthed sum
z5 = tf.matmul(h4,W5) + b5

# softmax activation (optional)
h5 = tf.nn.softmax(z5)

#################### END ##################################




# cross-entropy loss function (= -sum(yi * log(hi)) )
# TensorFlow provides the softmax_cross_entropy_with_logits function to avoid numerical stability
# problems with log(0) which is NaN
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=z5, labels=y)
cross_entropy = tf.reduce_mean(cross_entropy)

################### END ###############################

# accuracy of the trained model, between 0 (worst) and 1 (best)
correct_prediction = tf.equal(tf.argmax(h5, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# training
################# START CODE ########################
# the learning rate is: # 0.0001 + 0.003 * (1/e)^(step/2000)), i.e. exponential decay from 0.003->0.0001
lr = 0.0001 +  tf.train.exponential_decay(0.003, step_val, 2000, 1/math.e)
train_step = train_step = tf.train.GradientDescentOptimizer(lr).minimize(cross_entropy)

################# END ###############################

# %% [markdown]
# Start Session

# %%
#Start session

# initialize all variables
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %% [markdown]
# Train & visualize train/val loss and accuracy

# %%
history = training(x_train, y_train, x_val, y_val, sess, epochs=100, step=True)
# Out:
# EPOCH 1.0
#  train accuracy:0.06798182train loss: 2.3036492
#  ********* validation accuracy:0.1018 validation loss: 2.2997873
# EPOCH 2.0
#  train accuracy:0.08038182train loss: 2.2962697
#  ********* validation accuracy:0.1114 validation loss: 2.3080132
# EPOCH 3.0
#  train accuracy:0.09147273train loss: 2.3078847
#  ********* validation accuracy:0.1376 validation loss: 2.2999198
# EPOCH 4.0
#  train accuracy:0.15829091train loss: 2.30044
#  ********* validation accuracy:0.0704 validation loss: 2.3104808
# EPOCH 5.0
#  train accuracy:0.10943636train loss: 2.2965465
#  ********* validation accuracy:0.0882 validation loss: 2.2984378
# EPOCH 6.0
#  train accuracy:0.1369091train loss: 2.3002012
#  ********* validation accuracy:0.13 validation loss: 2.2992716
# EPOCH 7.0
#  train accuracy:0.07532727train loss: 2.3054848
#  ********* validation accuracy:0.0992 validation loss: 2.3039465
# EPOCH 8.0
#  train accuracy:0.046454545train loss: 2.3040192
#  ********* validation accuracy:0.0712 validation loss: 2.305582
# EPOCH 9.0
#  train accuracy:0.11332727train loss: 2.3101838
#  ********* validation accuracy:0.0772 validation loss: 2.2952495
# EPOCH 10.0
#  train accuracy:0.16892727train loss: 2.3083029
#  ********* validation accuracy:0.0624 validation loss: 2.306988
# EPOCH 11.0
#  train accuracy:0.11152727train loss: 2.3020785
#  ********* validation accuracy:0.1316 validation loss: 2.3019626
# EPOCH 12.0
#  train accuracy:0.0806train loss: 2.3138878
#  ********* validation accuracy:0.0968 validation loss: 2.3074286
# EPOCH 13.0
#  train accuracy:0.10723636train loss: 2.3041456
#  ********* validation accuracy:0.0956 validation loss: 2.310541
# EPOCH 14.0
#  train accuracy:0.0898train loss: 2.3030047
#  ********* validation accuracy:0.057 validation loss: 2.3042223
# EPOCH 15.0
#  train accuracy:0.055054545train loss: 2.3074105
#  ********* validation accuracy:0.115 validation loss: 2.3087294
# EPOCH 16.0
#  train accuracy:0.091054544train loss: 2.304995
#  ********* validation accuracy:0.1558 validation loss: 2.2997673
# EPOCH 17.0
#  train accuracy:0.08541818train loss: 2.3056412
#  ********* validation accuracy:0.1304 validation loss: 2.2969017
# EPOCH 18.0
#  train accuracy:0.10249091train loss: 2.3030365
#  ********* validation accuracy:0.0516 validation loss: 2.3079703
# EPOCH 19.0
#  train accuracy:0.082236364train loss: 2.3008204
#  ********* validation accuracy:0.0688 validation loss: 2.3027139
# EPOCH 20.0
#  train accuracy:0.09281818train loss: 2.3094583
#  ********* validation accuracy:0.0898 validation loss: 2.305693
# EPOCH 21.0
#  train accuracy:0.1545091train loss: 2.29673
#  ********* validation accuracy:0.1254 validation loss: 2.3038929
# EPOCH 22.0
#  train accuracy:0.106581815train loss: 2.3047292
#  ********* validation accuracy:0.113 validation loss: 2.3015614
# EPOCH 23.0
#  train accuracy:0.097890906train loss: 2.3057725
#  ********* validation accuracy:0.072 validation loss: 2.3073833
# EPOCH 24.0
#  train accuracy:0.085327275train loss: 2.3025577
#  ********* validation accuracy:0.1078 validation loss: 2.305517
# EPOCH 25.0
#  train accuracy:0.18229091train loss: 2.2979753
#  ********* validation accuracy:0.0754 validation loss: 2.3017972
# EPOCH 26.0
#  train accuracy:0.08194546train loss: 2.3035703
#  ********* validation accuracy:0.1474 validation loss: 2.3008087
# EPOCH 27.0
#  train accuracy:0.06910909train loss: 2.3075416
#  ********* validation accuracy:0.0722 validation loss: 2.3022277
# EPOCH 28.0
#  train accuracy:0.0884train loss: 2.309586
#  ********* validation accuracy:0.0958 validation loss: 2.3048656
# EPOCH 29.0
#  train accuracy:0.17585455train loss: 2.2939239
#  ********* validation accuracy:0.0836 validation loss: 2.3059433
# EPOCH 30.0
#  train accuracy:0.1263091train loss: 2.2998533
#  ********* validation accuracy:0.0946 validation loss: 2.3022704
# EPOCH 31.0
#  train accuracy:0.079527274train loss: 2.304452
#  ********* validation accuracy:0.0908 validation loss: 2.3024092
# EPOCH 32.0
#  train accuracy:0.15734546train loss: 2.3004391
#  ********* validation accuracy:0.073 validation loss: 2.3053296
# EPOCH 33.0
#  train accuracy:0.047472727train loss: 2.3078277
#  ********* validation accuracy:0.0864 validation loss: 2.3054593
# EPOCH 34.0
#  train accuracy:0.124145456train loss: 2.299138
#  ********* validation accuracy:0.1554 validation loss: 2.3032038
# EPOCH 35.0
#  train accuracy:0.07372727train loss: 2.303076
#  ********* validation accuracy:0.0948 validation loss: 2.3127975
# EPOCH 36.0
#  train accuracy:0.09641818train loss: 2.305074
#  ********* validation accuracy:0.1298 validation loss: 2.302996
# EPOCH 37.0
#  train accuracy:0.08356363train loss: 2.3121858
#  ********* validation accuracy:0.1518 validation loss: 2.3031108
# EPOCH 38.0
#  train accuracy:0.058345456train loss: 2.3049097
#  ********* validation accuracy:0.134 validation loss: 2.30179
# EPOCH 39.0
#  train accuracy:0.043436363train loss: 2.3173788
#  ********* validation accuracy:0.1284 validation loss: 2.3006144
# EPOCH 40.0
#  train accuracy:0.1452train loss: 2.2975302
#  ********* validation accuracy:0.1508 validation loss: 2.2998881
# EPOCH 41.0
#  train accuracy:0.110963635train loss: 2.2987955
#  ********* validation accuracy:0.0906 validation loss: 2.306153
# EPOCH 42.0
#  train accuracy:0.13038182train loss: 2.300453
#  ********* validation accuracy:0.0812 validation loss: 2.301936
# EPOCH 43.0
#  train accuracy:0.118072726train loss: 2.3014514
#  ********* validation accuracy:0.0866 validation loss: 2.3075309
# EPOCH 44.0
#  train accuracy:0.107363634train loss: 2.299076
#  ********* validation accuracy:0.071 validation loss: 2.310409
# EPOCH 45.0
#  train accuracy:0.091527276train loss: 2.3065991
#  ********* validation accuracy:0.202 validation loss: 2.2991257
# EPOCH 46.0
#  train accuracy:0.07903636train loss: 2.297761
#  ********* validation accuracy:0.1158 validation loss: 2.2999938
# EPOCH 47.0
#  train accuracy:0.050181817train loss: 2.3065426
#  ********* validation accuracy:0.1178 validation loss: 2.3018258
# EPOCH 48.0
#  train accuracy:0.10261818train loss: 2.305458
#  ********* validation accuracy:0.0504 validation loss: 2.3063896
# EPOCH 49.0
#  train accuracy:0.12034545train loss: 2.2964303
#  ********* validation accuracy:0.1054 validation loss: 2.301956
# EPOCH 50.0
#  train accuracy:0.09530909train loss: 2.303102
#  ********* validation accuracy:0.1238 validation loss: 2.304474
# EPOCH 51.0
#  train accuracy:0.08581818train loss: 2.3052115
#  ********* validation accuracy:0.1432 validation loss: 2.2998378
# EPOCH 52.0
#  train accuracy:0.13701819train loss: 2.2983096
#  ********* validation accuracy:0.0836 validation loss: 2.297421
# EPOCH 53.0
#  train accuracy:0.08630909train loss: 2.3070695
#  ********* validation accuracy:0.0812 validation loss: 2.2982557
# EPOCH 54.0
#  train accuracy:0.10767273train loss: 2.2997725
#  ********* validation accuracy:0.1274 validation loss: 2.3020442
# EPOCH 55.0
#  train accuracy:0.11838182train loss: 2.2989588
#  ********* validation accuracy:0.1124 validation loss: 2.3016844
# EPOCH 56.0
#  train accuracy:0.16train loss: 2.2932913
#  ********* validation accuracy:0.1298 validation loss: 2.2992637
# EPOCH 57.0
#  train accuracy:0.07681818train loss: 2.3038728
#  ********* validation accuracy:0.1246 validation loss: 2.2996871
# EPOCH 58.0
#  train accuracy:0.12450909train loss: 2.302417
#  ********* validation accuracy:0.085 validation loss: 2.308095
# EPOCH 59.0
#  train accuracy:0.096854545train loss: 2.3033774
#  ********* validation accuracy:0.095 validation loss: 2.3011582
# EPOCH 60.0
#  train accuracy:0.104345456train loss: 2.3012955
#  ********* validation accuracy:0.0934 validation loss: 2.3052692
# EPOCH 61.0
#  train accuracy:0.098train loss: 2.300823
#  ********* validation accuracy:0.131 validation loss: 2.306361
# EPOCH 62.0
#  train accuracy:0.078618184train loss: 2.308359
#  ********* validation accuracy:0.1374 validation loss: 2.2989774
# EPOCH 63.0
#  train accuracy:0.12554546train loss: 2.301204
#  ********* validation accuracy:0.1518 validation loss: 2.2902446
# EPOCH 64.0
#  train accuracy:0.07701818train loss: 2.3011022
#  ********* validation accuracy:0.159 validation loss: 2.3028514
# EPOCH 65.0
#  train accuracy:0.12149091train loss: 2.301026
#  ********* validation accuracy:0.129 validation loss: 2.2964468
# EPOCH 66.0
#  train accuracy:0.094train loss: 2.306094
#  ********* validation accuracy:0.1386 validation loss: 2.2937586
# EPOCH 67.0
#  train accuracy:0.09970909train loss: 2.3029473
#  ********* validation accuracy:0.062 validation loss: 2.3055325
# EPOCH 68.0
#  train accuracy:0.07727273train loss: 2.303062
#  ********* validation accuracy:0.0708 validation loss: 2.3120546
# EPOCH 69.0
#  train accuracy:0.1028train loss: 2.3058252
#  ********* validation accuracy:0.0748 validation loss: 2.3076332
# EPOCH 70.0
#  train accuracy:0.084163636train loss: 2.3034217
#  ********* validation accuracy:0.1324 validation loss: 2.2968953
# EPOCH 71.0
#  train accuracy:0.07147273train loss: 2.303998
#  ********* validation accuracy:0.1038 validation loss: 2.2997649
# EPOCH 72.0
#  train accuracy:0.10278182train loss: 2.3017385
#  ********* validation accuracy:0.1264 validation loss: 2.306312
# EPOCH 73.0
#  train accuracy:0.13314545train loss: 2.3061821
#  ********* validation accuracy:0.0652 validation loss: 2.3040972
# EPOCH 74.0
#  train accuracy:0.09509091train loss: 2.3005524
#  ********* validation accuracy:0.138 validation loss: 2.3027809
# EPOCH 75.0
#  train accuracy:0.0998train loss: 2.3015273
#  ********* validation accuracy:0.0818 validation loss: 2.3065338
# EPOCH 76.0
#  train accuracy:0.18118182train loss: 2.3001285
#  ********* validation accuracy:0.1054 validation loss: 2.3000634
# EPOCH 77.0
#  train accuracy:0.10834546train loss: 2.3044536
#  ********* validation accuracy:0.0956 validation loss: 2.3015518
# EPOCH 78.0
#  train accuracy:0.13227272train loss: 2.3010478
#  ********* validation accuracy:0.1648 validation loss: 2.30259
# EPOCH 79.0
#  train accuracy:0.087927274train loss: 2.3043404
#  ********* validation accuracy:0.129 validation loss: 2.2981281
# EPOCH 80.0
#  train accuracy:0.14474545train loss: 2.3020957
#  ********* validation accuracy:0.0506 validation loss: 2.3106406
# EPOCH 81.0
#  train accuracy:0.080690905train loss: 2.305838
#  ********* validation accuracy:0.0636 validation loss: 2.3044071
# EPOCH 82.0
#  train accuracy:0.09787273train loss: 2.304845
#  ********* validation accuracy:0.0962 validation loss: 2.3059835
# EPOCH 83.0
#  train accuracy:0.15354545train loss: 2.300323
#  ********* validation accuracy:0.18 validation loss: 2.2989106
# EPOCH 84.0
#  train accuracy:0.138train loss: 2.2966416
#  ********* validation accuracy:0.0858 validation loss: 2.3052802
# EPOCH 85.0
#  train accuracy:0.10190909train loss: 2.30449
#  ********* validation accuracy:0.1026 validation loss: 2.3026936
# EPOCH 86.0
#  train accuracy:0.08652727train loss: 2.3066056
#  ********* validation accuracy:0.135 validation loss: 2.30093
# EPOCH 87.0
#  train accuracy:0.11829091train loss: 2.3005686
#  ********* validation accuracy:0.0734 validation loss: 2.3092191
# EPOCH 88.0
#  train accuracy:0.07489091train loss: 2.3056622
#  ********* validation accuracy:0.0692 validation loss: 2.3012743
# EPOCH 89.0
#  train accuracy:0.12292727train loss: 2.2979393
#  ********* validation accuracy:0.079 validation loss: 2.3037157
# EPOCH 90.0
#  train accuracy:0.08685455train loss: 2.3018203
#  ********* validation accuracy:0.1174 validation loss: 2.3040948
# EPOCH 91.0
#  train accuracy:0.06750909train loss: 2.3023908
#  ********* validation accuracy:0.0992 validation loss: 2.3046775
# EPOCH 92.0
#  train accuracy:0.076train loss: 2.3065867
#  ********* validation accuracy:0.083 validation loss: 2.298765
# EPOCH 93.0
#  train accuracy:0.07516364train loss: 2.3062081
#  ********* validation accuracy:0.105 validation loss: 2.297739
# EPOCH 94.0
#  train accuracy:0.09843636train loss: 2.3032355
#  ********* validation accuracy:0.1794 validation loss: 2.2959285
# EPOCH 95.0
#  train accuracy:0.049872726train loss: 2.308093
#  ********* validation accuracy:0.0568 validation loss: 2.3036225
# EPOCH 96.0
#  train accuracy:0.08570909train loss: 2.3034832
#  ********* validation accuracy:0.135 validation loss: 2.2942538
# EPOCH 97.0
#  train accuracy:0.21025455train loss: 2.2916996
#  ********* validation accuracy:0.064 validation loss: 2.3059916
# EPOCH 98.0
#  train accuracy:0.1054train loss: 2.2975137
#  ********* validation accuracy:0.079 validation loss: 2.3057563
# EPOCH 99.0
#  train accuracy:0.06927273train loss: 2.3060842
#  ********* validation accuracy:0.0966 validation loss: 2.3063722
# EPOCH 100.0
#  train accuracy:0.11481818train loss: 2.302705
#  ********* validation accuracy:0.1438 validation loss: 2.301582

# %%
plot_history(history)

# %% [markdown]
# Test Accuracy

# %%
a_test, c_test  = sess.run([accuracy, cross_entropy], feed_dict={X: x_test, y: y_test})

print('Test accuracy is: ', ("%.2f"%(a_test*100))+'%')
# Out:
# Test accuracy is:  4.00%

# %%
sess.close()

# %% [markdown]
# ## 8. Use dropout

# %% [markdown]
# Computational graph

# %%
#Create computational graph

# input 
X = tf.placeholder(tf.float32, [None,784])
# labels (onehot encoded)
y = tf.placeholder(tf.float32, [None, 10])
# step for variable learning rate
step_val = tf.placeholder(tf.int32)

# variable learning rate
lr = tf.placeholder(tf.float32)
# Probability of keeping a node during dropout = 1.0 at test time (no dropout) and 0.75 at training time
pkeep_val = tf.placeholder(tf.float32)


''' First hidden layer with 200 neurons'''
################## START CODE #########################
# weights 1
W1 = tf.Variable(tf.truncated_normal([784,200] , stddev = 0.1))
# biases 1
b1 = tf.Variable(tf.zeros([200]))

# weigthed sum
z1 = tf.matmul(X, W1) + b1

#  activation
h1 = tf.nn.relu(z1)

# dropout
h1d = tf.nn.dropout(h1, pkeep_val)
################## END #########################

''' Second hidden layer with 100 neurons'''
################## START CODE #########################
# weights 1
W2 = tf.Variable(tf.truncated_normal([200,100] , stddev = 0.1))
# biases 1
b2 = tf.Variable(tf.zeros([100]))

# weigthed sum
z2 = tf.matmul(h1d, W2) + b2

# activation
h2 = tf.nn.relu(z2)

# dropout
h2d = tf.nn.dropout(h2, pkeep_val)


####################### END #############################

''' third Layer with 60 neurons'''
##################### START CODE #########################
# weights 2
W3 = tf.Variable(tf.truncated_normal([100, 60], stddev=0.1))
# biases 2
b3 = tf.Variable(tf.zeros([60]))

# weigthed sum
z3 = tf.matmul(h2d, W3) + b3

# activation
h3 = tf.nn.relu(z3)

# dropout
h3d = tf.nn.dropout(h3, pkeep_val)

#################### END ##################################

''' fourth Layer with 30 neurons'''
##################### START CODE #########################
# weights 2
W4 = tf.Variable(tf.truncated_normal([60,30] , stddev = 0.1))
# biases 2
b4 = tf.Variable(tf.zeros([30]))

# weigthed sum
z4 = tf.matmul(h3,W4) + b4

# activation 
h4 = tf.nn.relu(z4)

# dropout
h4d = tf.nn.dropout(h4, pkeep_val)



#################### END ##################################

''' fifth/output Layer with 10 neurons'''
##################### START CODE #########################
# weights 2
W5 = tf.Variable(tf.truncated_normal([30, 10], stddev=0.1))#None
# biases 2
b5 = tf.Variable(tf.zeros([10]))
# weigthed sum
z5 = tf.matmul(h4,W5) + b5

# softmax activation
h5 = tf.nn.softmax(z5)

#################### END ##################################





# cross-entropy loss function (= -sum(yi * log(hi)) )
# TensorFlow provides the softmax_cross_entropy_with_logits function to avoid numerical stability
# problems with log(0) which is NaN
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=z5, labels=y)
cross_entropy = tf.reduce_mean(cross_entropy)

################### END ###############################

# accuracy of the trained model, between 0 (worst) and 1 (best)
correct_prediction = tf.equal(tf.argmax(h5, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# training
################# START CODE ########################
# the learning rate is: # 0.0001 + 0.003 * (1/e)^(step/2000)), i.e. exponential decay from 0.003->0.0001
lr = 0.0001 +  tf.train.exponential_decay(0.003, step_val, 2000, 1/math.e)
train_step = tf.train.GradientDescentOptimizer(lr).minimize(cross_entropy)


################# END ###############################

# %% [markdown]
# Start session

# %%
#Start session

# initialize all variables
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %% [markdown]
# Train & visualize train/val loss and accuracy

# %%
history = training(x_train, y_train, x_val, y_val, sess, epochs=100, step=True, pkeep=0.75)
# Out:
# EPOCH 1.0
#  train accuracy:0.2829818train loss: 2.169266
#  ********* validation accuracy:0.3622 validation loss: 2.1281605
# EPOCH 2.0
#  train accuracy:0.34065455train loss: 1.8483298
#  ********* validation accuracy:0.3784 validation loss: 1.7559842
# EPOCH 3.0
#  train accuracy:0.39905456train loss: 1.5640172
#  ********* validation accuracy:0.4676 validation loss: 1.4468949
# EPOCH 4.0
#  train accuracy:0.44910908train loss: 1.4195824
#  ********* validation accuracy:0.5388 validation loss: 1.2884215
# EPOCH 5.0
#  train accuracy:0.4749091train loss: 1.3396031
#  ********* validation accuracy:0.5688 validation loss: 1.1986016
# EPOCH 6.0
#  train accuracy:0.49185455train loss: 1.2885642
#  ********* validation accuracy:0.5828 validation loss: 1.1425307
# EPOCH 7.0
#  train accuracy:0.50652725train loss: 1.2495712
#  ********* validation accuracy:0.5938 validation loss: 1.1046357
# EPOCH 8.0
#  train accuracy:0.5124364train loss: 1.2266889
#  ********* validation accuracy:0.5998 validation loss: 1.0777662
# EPOCH 9.0
#  train accuracy:0.5220182train loss: 1.2094766
#  ********* validation accuracy:0.6044 validation loss: 1.0577224
# EPOCH 10.0
#  train accuracy:0.5267091train loss: 1.1922661
#  ********* validation accuracy:0.6074 validation loss: 1.0425048
# EPOCH 11.0
#  train accuracy:0.5308727train loss: 1.1811198
#  ********* validation accuracy:0.6096 validation loss: 1.0305556
# EPOCH 12.0
#  train accuracy:0.5377091train loss: 1.1698556
#  ********* validation accuracy:0.6134 validation loss: 1.0208778
# EPOCH 13.0
#  train accuracy:0.5375091train loss: 1.1630862
#  ********* validation accuracy:0.6164 validation loss: 1.0128293
# EPOCH 14.0
#  train accuracy:0.5394545train loss: 1.1584784
#  ********* validation accuracy:0.6176 validation loss: 1.005996
# EPOCH 15.0
#  train accuracy:0.541train loss: 1.1520236
#  ********* validation accuracy:0.6174 validation loss: 1.0000532
# EPOCH 16.0
#  train accuracy:0.5442182train loss: 1.1470244
#  ********* validation accuracy:0.6192 validation loss: 0.9947788
# EPOCH 17.0
#  train accuracy:0.5442182train loss: 1.1438875
#  ********* validation accuracy:0.6216 validation loss: 0.9900163
# EPOCH 18.0
#  train accuracy:0.5474182train loss: 1.13724
#  ********* validation accuracy:0.6222 validation loss: 0.9855955
# EPOCH 19.0
#  train accuracy:0.54858184train loss: 1.1328422
#  ********* validation accuracy:0.6236 validation loss: 0.9815111
# EPOCH 20.0
#  train accuracy:0.54874545train loss: 1.1281102
#  ********* validation accuracy:0.6252 validation loss: 0.9776703
# EPOCH 21.0
#  train accuracy:0.5518364train loss: 1.1256148
#  ********* validation accuracy:0.6266 validation loss: 0.9740082
# EPOCH 22.0
#  train accuracy:0.5540182train loss: 1.1208357
#  ********* validation accuracy:0.6264 validation loss: 0.97050995
# EPOCH 23.0
#  train accuracy:0.5544909train loss: 1.1190938
#  ********* validation accuracy:0.6278 validation loss: 0.96712625
# EPOCH 24.0
#  train accuracy:0.5566364train loss: 1.1134821
#  ********* validation accuracy:0.6286 validation loss: 0.9638461
# EPOCH 25.0
#  train accuracy:0.55596364train loss: 1.1099375
#  ********* validation accuracy:0.6296 validation loss: 0.9606857
# EPOCH 26.0
#  train accuracy:0.55889094train loss: 1.1085104
#  ********* validation accuracy:0.6306 validation loss: 0.95759845
# EPOCH 27.0
#  train accuracy:0.5585818train loss: 1.1063733
#  ********* validation accuracy:0.632 validation loss: 0.9545953
# EPOCH 28.0
#  train accuracy:0.56225455train loss: 1.1012039
#  ********* validation accuracy:0.6332 validation loss: 0.95161074
# EPOCH 29.0
#  train accuracy:0.56134546train loss: 1.1002028
#  ********* validation accuracy:0.6346 validation loss: 0.9487381
# EPOCH 30.0
#  train accuracy:0.5625455train loss: 1.0987909
#  ********* validation accuracy:0.6362 validation loss: 0.9459184
# EPOCH 31.0
#  train accuracy:0.56225455train loss: 1.0937846
#  ********* validation accuracy:0.6362 validation loss: 0.94314504
# EPOCH 32.0
#  train accuracy:0.56854546train loss: 1.0881866
#  ********* validation accuracy:0.6364 validation loss: 0.9404196
# EPOCH 33.0
#  train accuracy:0.5649818train loss: 1.086142
#  ********* validation accuracy:0.6372 validation loss: 0.9377146
# EPOCH 34.0
#  train accuracy:0.5686727train loss: 1.0847939
#  ********* validation accuracy:0.6378 validation loss: 0.93512654
# EPOCH 35.0
#  train accuracy:0.5683454train loss: 1.0830165
#  ********* validation accuracy:0.6388 validation loss: 0.93249774
# EPOCH 36.0
#  train accuracy:0.57356364train loss: 1.0779535
#  ********* validation accuracy:0.6406 validation loss: 0.9299454
# EPOCH 37.0
#  train accuracy:0.5738364train loss: 1.0738249
#  ********* validation accuracy:0.6416 validation loss: 0.9274546
# EPOCH 38.0
#  train accuracy:0.5709636train loss: 1.0770891
#  ********* validation accuracy:0.6418 validation loss: 0.9249667
# EPOCH 39.0
#  train accuracy:0.5728727train loss: 1.0716621
#  ********* validation accuracy:0.6424 validation loss: 0.92254806
# EPOCH 40.0
#  train accuracy:0.57478184train loss: 1.0649778
#  ********* validation accuracy:0.6432 validation loss: 0.9201425
# EPOCH 41.0
#  train accuracy:0.57534546train loss: 1.068437
#  ********* validation accuracy:0.6448 validation loss: 0.9177626
# EPOCH 42.0
#  train accuracy:0.5779273train loss: 1.0646183
#  ********* validation accuracy:0.6456 validation loss: 0.9154332
# EPOCH 43.0
#  train accuracy:0.5767273train loss: 1.0584426
#  ********* validation accuracy:0.646 validation loss: 0.9131155
# EPOCH 44.0
#  train accuracy:0.5786727train loss: 1.0608106
#  ********* validation accuracy:0.6462 validation loss: 0.91085774
# EPOCH 45.0
#  train accuracy:0.5797273train loss: 1.0565218
#  ********* validation accuracy:0.6462 validation loss: 0.9086322
# EPOCH 46.0
#  train accuracy:0.58003634train loss: 1.0541635
#  ********* validation accuracy:0.646 validation loss: 0.90641963
# EPOCH 47.0
#  train accuracy:0.58003634train loss: 1.0500087
#  ********* validation accuracy:0.6458 validation loss: 0.90423924
# EPOCH 48.0
#  train accuracy:0.5824909train loss: 1.0477724
#  ********* validation accuracy:0.6466 validation loss: 0.9020946
# EPOCH 49.0
#  train accuracy:0.5851455train loss: 1.0453283
#  ********* validation accuracy:0.6476 validation loss: 0.8999395
# EPOCH 50.0
#  train accuracy:0.5889636train loss: 1.040629
#  ********* validation accuracy:0.6482 validation loss: 0.8978088
# EPOCH 51.0
#  train accuracy:0.58707273train loss: 1.043422
#  ********* validation accuracy:0.648 validation loss: 0.89573896
# EPOCH 52.0
#  train accuracy:0.5883818train loss: 1.0407959
#  ********* validation accuracy:0.6486 validation loss: 0.8936998
# EPOCH 53.0
#  train accuracy:0.58565456train loss: 1.0389063
#  ********* validation accuracy:0.6488 validation loss: 0.89166456
# EPOCH 54.0
#  train accuracy:0.59034544train loss: 1.0359046
#  ********* validation accuracy:0.6494 validation loss: 0.88964677
# EPOCH 55.0
#  train accuracy:0.58794546train loss: 1.0346308
#  ********* validation accuracy:0.6506 validation loss: 0.8876672
# EPOCH 56.0
#  train accuracy:0.5903091train loss: 1.0286646
#  ********* validation accuracy:0.6512 validation loss: 0.885726
# EPOCH 57.0
#  train accuracy:0.59163636train loss: 1.0283324
#  ********* validation accuracy:0.6512 validation loss: 0.88376796
# EPOCH 58.0
#  train accuracy:0.59325457train loss: 1.0254223
#  ********* validation accuracy:0.6512 validation loss: 0.8818212
# EPOCH 59.0
#  train accuracy:0.5913091train loss: 1.0257062
#  ********* validation accuracy:0.6512 validation loss: 0.8799148
# EPOCH 60.0
#  train accuracy:0.59352726train loss: 1.02272
#  ********* validation accuracy:0.6516 validation loss: 0.8779959
# EPOCH 61.0
#  train accuracy:0.5956909train loss: 1.019297
#  ********* validation accuracy:0.6518 validation loss: 0.87613994
# EPOCH 62.0
#  train accuracy:0.5965273train loss: 1.0187289
#  ********* validation accuracy:0.6534 validation loss: 0.87426174
# EPOCH 63.0
#  train accuracy:0.5957818train loss: 1.0169507
#  ********* validation accuracy:0.6542 validation loss: 0.8724324
# EPOCH 64.0
#  train accuracy:0.5953818train loss: 1.0139405
#  ********* validation accuracy:0.6548 validation loss: 0.8705996
# EPOCH 65.0
#  train accuracy:0.6004364train loss: 1.0109602
#  ********* validation accuracy:0.6562 validation loss: 0.86879396
# EPOCH 66.0
#  train accuracy:0.6006909train loss: 1.0104316
#  ********* validation accuracy:0.6568 validation loss: 0.86700076
# EPOCH 67.0
#  train accuracy:0.59825456train loss: 1.0088707
#  ********* validation accuracy:0.6574 validation loss: 0.8652175
# EPOCH 68.0
#  train accuracy:0.6019091train loss: 1.0054082
#  ********* validation accuracy:0.658 validation loss: 0.863421
# EPOCH 69.0
#  train accuracy:0.5995273train loss: 1.0076461
#  ********* validation accuracy:0.6582 validation loss: 0.8616443
# EPOCH 70.0
#  train accuracy:0.6018train loss: 1.0013746
#  ********* validation accuracy:0.6598 validation loss: 0.85992736
# EPOCH 71.0
#  train accuracy:0.6031273train loss: 1.0035646
#  ********* validation accuracy:0.6598 validation loss: 0.85818154
# EPOCH 72.0
#  train accuracy:0.6042182train loss: 1.0004237
#  ********* validation accuracy:0.6598 validation loss: 0.85646784
# EPOCH 73.0
#  train accuracy:0.60565454train loss: 0.9946001
#  ********* validation accuracy:0.6598 validation loss: 0.8547692
# EPOCH 74.0
#  train accuracy:0.6076train loss: 0.9942004
#  ********* validation accuracy:0.66 validation loss: 0.8530908
# EPOCH 75.0
#  train accuracy:0.60832727train loss: 0.99230725
#  ********* validation accuracy:0.6616 validation loss: 0.8513982
# EPOCH 76.0
#  train accuracy:0.60827273train loss: 0.9919969
#  ********* validation accuracy:0.6614 validation loss: 0.84973496
# EPOCH 77.0
#  train accuracy:0.61005455train loss: 0.99099404
#  ********* validation accuracy:0.6614 validation loss: 0.8481017
# EPOCH 78.0
#  train accuracy:0.6088909train loss: 0.9849071
#  ********* validation accuracy:0.6626 validation loss: 0.8464089
# EPOCH 79.0
#  train accuracy:0.6119091train loss: 0.98612297
#  ********* validation accuracy:0.6628 validation loss: 0.8448213
# EPOCH 80.0
#  train accuracy:0.6114182train loss: 0.98486614
#  ********* validation accuracy:0.663 validation loss: 0.843201
# EPOCH 81.0
#  train accuracy:0.6109091train loss: 0.981649
#  ********* validation accuracy:0.6636 validation loss: 0.841572
# EPOCH 82.0
#  train accuracy:0.61252725train loss: 0.9788892
#  ********* validation accuracy:0.6634 validation loss: 0.83993137
# EPOCH 83.0
#  train accuracy:0.61129093train loss: 0.97783095
#  ********* validation accuracy:0.6638 validation loss: 0.8383569
# EPOCH 84.0
#  train accuracy:0.61605453train loss: 0.97333664
#  ********* validation accuracy:0.6638 validation loss: 0.8367854
# EPOCH 85.0
#  train accuracy:0.61483634train loss: 0.97694147
#  ********* validation accuracy:0.665 validation loss: 0.8352049
# EPOCH 86.0
#  train accuracy:0.61243635train loss: 0.97388977
#  ********* validation accuracy:0.6654 validation loss: 0.83361757
# EPOCH 87.0
#  train accuracy:0.61767274train loss: 0.97059417
#  ********* validation accuracy:0.6664 validation loss: 0.8320568
# EPOCH 88.0
#  train accuracy:0.6164909train loss: 0.9668624
#  ********* validation accuracy:0.667 validation loss: 0.8304945
# EPOCH 89.0
#  train accuracy:0.6190909train loss: 0.9663551
#  ********* validation accuracy:0.6668 validation loss: 0.82896984
# EPOCH 90.0
#  train accuracy:0.6196train loss: 0.96597666
#  ********* validation accuracy:0.6672 validation loss: 0.8274262
# EPOCH 91.0
#  train accuracy:0.61743635train loss: 0.96745455
#  ********* validation accuracy:0.6684 validation loss: 0.8259375
# EPOCH 92.0
#  train accuracy:0.6205091train loss: 0.9662434
#  ********* validation accuracy:0.668 validation loss: 0.8243996
# EPOCH 93.0
#  train accuracy:0.62145454train loss: 0.9618209
#  ********* validation accuracy:0.6686 validation loss: 0.8228783
# EPOCH 94.0
#  train accuracy:0.6215636train loss: 0.9596503
#  ********* validation accuracy:0.6688 validation loss: 0.82135665
# EPOCH 95.0
#  train accuracy:0.62192726train loss: 0.95864165
#  ********* validation accuracy:0.6692 validation loss: 0.8198881
# EPOCH 96.0
#  train accuracy:0.6218909train loss: 0.9585817
#  ********* validation accuracy:0.67 validation loss: 0.8184485
# EPOCH 97.0
#  train accuracy:0.62307274train loss: 0.95539683
#  ********* validation accuracy:0.6702 validation loss: 0.8169455
# EPOCH 98.0
#  train accuracy:0.6246182train loss: 0.9530011
#  ********* validation accuracy:0.6704 validation loss: 0.8154837
# EPOCH 99.0
#  train accuracy:0.6245273train loss: 0.9515228
#  ********* validation accuracy:0.6708 validation loss: 0.8140395
# EPOCH 100.0
#  train accuracy:0.62845457train loss: 0.9492218
#  ********* validation accuracy:0.672 validation loss: 0.8125668

# %%
plot_history(history)

# %% [markdown]
# Test Accuracy

# %%
a_test, c_test  = sess.run([accuracy, cross_entropy], feed_dict={X: x_test, y: y_test, pkeep_val: 1})

print('Test accuracy is: ', ("%.2f"%(a_test*100))+'%')
# Out:
# Test accuracy is:  64.85%

# %% [markdown]
# ## 9. Convolutional Neural Networks

# %%
''' Let Your Imagination Run Wild'''
